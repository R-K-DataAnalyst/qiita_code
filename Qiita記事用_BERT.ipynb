# %%
import numpy as np
import pandas as pd
import sqlite3
import json
import glob
import gensim
import tqdm as tq
from tqdm import tqdm
import scipy
import gc
import pickle
import os
import collections

import string
import re
import MeCab
import gensim
from gensim.models import word2vec
from gensim.models import KeyedVectors

import torch
from transformers import BertJapaneseTokenizer, BertModel, BertForMaskedLM
from transformers import BertConfig
from transformers import BertForMaskedLM
from transformers import DataCollatorForLanguageModeling
from transformers import LineByLineTextDataset
from transformers import TrainingArguments
from transformers import Trainer
import datasets

# %% [markdown]
# # chABSA-datasetの前処理

# %%
# ファイル一覧
data_dir = "bert_test/chABSA-dataset"
path_list = glob.glob(data_dir+'/*.json')
print("jsonファイル数 ",len(path_list))
# Out:
# jsonファイル数  230

# %%
# json確認
with open(path_list[0], "br") as f:
    j =  json.load(f)
sentences = j["sentences"]  # sentencesにはデータ数分のデータが格納されている。
print("1つ目のファイル内のデータ数チェック：", len(sentences))
print("sentences：", sentences)
# Out:
# 1つ目のファイル内のデータ数チェック： 36
# sentences： [{'sentence_id': 0, 'sentence': '当連結会計年度におけるわが国経済は、政府の経済政策や日銀の金融緩和策により、企業業績、雇用・所得環境は改善し、景気も緩やかな回復基調のうちに推移いたしましたが、中国をはじめとするアジア新興国経済の減速懸念や、英国の欧州連合（ＥＵ）離脱決定、米国新政権への移行など、引き続き先行きは不透明な状況となっております', 'opinions': [{'target': 'わが国経済', 'category': 'NULL#general', 'polarity': 'neutral', 'from': 11, 'to': 16}, {'target': '企業業績', 'category': 'NULL#general', 'polarity': 'positive', 'from': 38, 'to': 42}, {'target': '雇用', 'category': 'NULL#general', 'polarity': 'positive', 'from': 43, 'to': 45}, {'target': '所得環境', 'category': 'NULL#general', 'polarity': 'positive', 'from': 46, 'to': 50}, {'target': '景気', 'category': 'NULL#general', 'polarity': 'positive', 'from': 55, 'to': 57}]}, {'sentence_id': 1, 'sentence': '当社グループを取り巻く環境は、実質賃金が伸び悩むなか、消費者の皆様の生活防衛意識の高まりや節約志向により、個人消費は本格的な改善には至らず、また少子高齢化、人口減少による社会構造の変化、雇用改善に伴う労働コストの上昇、企業間競争の激化など、引き続き厳しい状況となりました', 'opinions': [{'target': '環境', 'category': 'NULL#general', 'polarity': 'negative', 'from': 11, 'to': 13}, {'target': '実質賃金', 'category': 'NULL#general', 'polarity': 'negative', 'from': 15, 'to': 19}, {'target': '個人消費', 'category': 'NULL#general', 'polarity': 'negative', 'from': 53, 'to': 57}, {'target': '労働コスト', 'category': 'NULL#cost', 'polarity': 'negative', 'from': 100, 'to': 105}, {'target': '企業間競争', 'category': 'NULL#general', 'polarity': 'negative', 'from': 109, 'to': 114}]}, {'sentence_id': 2, 'sentence': 'このような環境の中、当社グループはきのこ事業を中心として、健康食材である「きのこ」の研究開発、生産、販売を通して、より多くの皆様へ、おいしさと健康をお届けできるよう事業活動を行ってまいりました', 'opinions': []}, {'sentence_id': 3, 'sentence': 'また、平成26年に策定いたしました中期経営計画の見直しを行い、市況に左右されない事業ポートフォリオの構築を目指した活動を推進し、おいしくて健康な「きのこ食文化の創造」と「企業の発展」に向け邁進してまいりました', 'opinions': []}, {'sentence_id': 4, 'sentence': '以上の結果、当連結会計年度の当社グループの業績は、売上高631億19百万円（前期比3.5％増）、営業利益34億30百万円（前期比0.1％増）、経常利益43億79百万円（前期比7.5％増）、親会社株主に帰属する当期純利益は28億28百万円（前期比8.9％増）となりました', 'opinions': [{'target': '当社グループ', 'category': 'company#sales', 'polarity': 'positive', 'from': 14, 'to': 20}, {'target': '当社グループ', 'category': 'company#profit', 'polarity': 'positive', 'from': 14, 'to': 20}]}, {'sentence_id': 5, 'sentence': 'なお、当連結会計年度の生産量は、ブナピーを含めブナシメジ42,602ｔ（同5.5％増）、エリンギ19,250ｔ（同0.2％減）、マイタケ14,281ｔ（同4.3％増）となりました', 'opinions': [{'target': 'ブナシメジ', 'category': 'product#amount', 'polarity': 'positive', 'from': 23, 'to': 28}, {'target': 'エリンギ', 'category': 'product#amount', 'polarity': 'negative', 'from': 44, 'to': 48}, {'target': 'マイタケ', 'category': 'product#amount', 'polarity': 'positive', 'from': 64, 'to': 68}]}, {'sentence_id': 6, 'sentence': '当連結会計年度の各セグメントの概況は次のとおりであります', 'opinions': []}, {'sentence_id': 7, 'sentence': '「国内きのこ事業」', 'opinions': []}, {'sentence_id': 8, 'sentence': '生産部門におきましては、衛生管理を徹底し、安定栽培と品質の向上に努めてまいりました', 'opinions': []}, {'sentence_id': 9, 'sentence': '平成27年４月の火災により生産を休止していた苫小牧第一きのこセンターが、工場を再建し、平成28年４月27日よりブナシメジの収穫・出荷を再開したことや、カットブナシメジ専用工場として新設した富山きのこセンターが平成28年９月上旬から収穫・出荷を開始したことにより、ブナシメジの生産量は増加いたしました', 'opinions': [{'target': 'ブナシメジ', 'category': 'product#amount', 'polarity': 'positive', 'from': 131, 'to': 136}]}, {'sentence_id': 10, 'sentence': 'また、改修のため一時生産を休止しておりました広川きのこセンターにおきまして、平成28年９月上旬より霜降りひらたけの収穫・出荷を開始したことなどにより、きのこ全体の生産量は増加いたしました', 'opinions': [{'target': 'きのこ', 'category': 'product#amount', 'polarity': 'positive', 'from': 75, 'to': 78}]}, {'sentence_id': 11, 'sentence': '研究部門におきましては、品質管理体制の強化、付加価値の高い新商品の開発およびきのこの薬理効果や機能性の追求に取り組んでまいりました', 'opinions': []}, {'sentence_id': 12, 'sentence': '特に、平成27年７月に完成したシイタケ栽培技術研究施設におきまして、シイタケの大量・安定栽培に向けた研究に注力いたしました', 'opinions': []}, {'sentence_id': 13, 'sentence': '営業部門におきましては、鮮度に拘った営業活動を行う一方、きのこによる健康と美容価値の創出が消費に結びつくものとして、引き続き「菌活」の提唱を行い、消費の拡大に努めてまいりました', 'opinions': []}, {'sentence_id': 14, 'sentence': '春から夏にかけましては個人消費の低迷などにより、きのこの価格は厳しい状況で推移いたしました', 'opinions': [{'target': 'きのこ', 'category': 'product#price', 'polarity': 'negative', 'from': 24, 'to': 27}, {'target': '個人消費', 'category': 'NULL#general', 'polarity': 'negative', 'from': 11, 'to': 15}]}, {'sentence_id': 15, 'sentence': '反面、秋から冬にかけましては天候不順などによる野菜価格の高騰により、きのこの価格は堅調に推移いたしました', 'opinions': [{'target': '野菜価格', 'ca ...

# %%
# idと文章のdf作成
def makeSentenceDf(path_list):
    sentenceDf = pd.DataFrame()
    for file in tqdm(path_list):
        with open(file, "br") as f:
            j =  json.load(f)
        sentences = j["sentences"]
        idsList = []
        sList = []
        for obj in sentences:
            ids = obj["sentence_id"]
            s = obj["sentence"]  #文章
            sList.append(s)
            idsList.append(ids)
        tmp = pd.DataFrame({'sentence_id':idsList, 'sentence':sList})
        sentenceDf = pd.concat([sentenceDf, tmp])
    return sentenceDf.reset_index(drop=True)

# %%
# df作成
sentenceDf = makeSentenceDf(path_list[:])
display(sentenceDf.head())
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 230/230 [00:01<00:00, 180.81it/s]
#    sentence_id                                           sentence
# 0            0  当連結会計年度におけるわが国経済は、政府の経済政策や日銀の金融緩和策により、企業業績、雇用・...
# 1            1  当社グループを取り巻く環境は、実質賃金が伸び悩むなか、消費者の皆様の生活防衛意識の高まりや節...
# 2            2  このような環境の中、当社グループはきのこ事業を中心として、健康食材である「きのこ」の研究開発...
# 3            3  また、平成26年に策定いたしました中期経営計画の見直しを行い、市況に左右されない事業ポートフ...
# 4            4  以上の結果、当連結会計年度の当社グループの業績は、売上高631億19百万円（前期比3.5％増...

# %%
# 丸囲い数字のコード取得
def get_marumoji(val):
    # ①を文字コードに変換[bytes型]
    maru_date = "①".encode("UTF8")
    # ①を文字コードに変換[int型]
    maru_code = int.from_bytes(maru_date, 'big')
    # 文字コードの変換
    maru_code += val - 1
    # 文字コードを文字に変換して返却
    return maru_code.to_bytes(4, "big").decode("UTF8")[1]

# 小文字化、記号・丸囲い数字除去、全角を半角など前処理関数
def preprocessing(text):    
    text = text.lower()  # 小文字化
    text = re.sub('\r\n','',text)  # \r\nをdelete
    text = re.sub(r'\d+','',text)  # 数字列をdelete
    ZEN = "".join(chr(0xff01 + i) for i in range(94))  # 全角文字列一覧
    HAN = "".join(chr(0x21 + i) for i in range(94))  # 半角文字列一覧
    ALL=re.sub(r'[a-zA-Zａ-ｚＡ-Ｚ\d]+','',ZEN+HAN)
    code_regex = re.compile('['+'〜'+'、'+'。'+'~'+'*'+'＊'+ALL+'「'+'」'+']')
    text = code_regex.sub(' ', text)  # 記号を消す
    
    maru_int = []
    for i in range(1,100):
        try:
            tmp = get_marumoji(i)
            maru_int.append(tmp)
        except UnicodeDecodeError:
            'UnicodeDecodeError, Skip a processing'
    code_regex = re.compile('['+"".join(i for i in maru_int)+']')
    text = code_regex.sub(' ', text)  # 丸囲い数字を消す
    
    ZEN = "".join(chr(0xff01 + i) for i in range(94))
    HAN = "".join(chr(0x21 + i) for i in range(94))
    ZEN2HAN = str.maketrans(ZEN, HAN)
    HAN2ZEN = str.maketrans(HAN, ZEN)
    text=text.translate(ZEN2HAN)  # 全角を半角に
    return text

# %%
# 前処理した文章をdfの新たな列に入れる
sentenceDf['preprocessingSentence'] = [preprocessing(text) for text in sentenceDf['sentence']]
sentenceDf = sentenceDf[sentenceDf['preprocessingSentence'].apply(lambda x:len(x)>0)]  # 何もない行は消す
display(sentenceDf.head())
# Out:
#    sentence_id                                           sentence  \
# 0            0  当連結会計年度におけるわが国経済は、政府の経済政策や日銀の金融緩和策により、企業業績、雇用・...
# 1            1  当社グループを取り巻く環境は、実質賃金が伸び悩むなか、消費者の皆様の生活防衛意識の高まりや節...
# 2            2  このような環境の中、当社グループはきのこ事業を中心として、健康食材である「きのこ」の研究開発...
# 3            3  また、平成26年に策定いたしました中期経営計画の見直しを行い、市況に左右されない事業ポートフ...
# 4            4  以上の結果、当連結会計年度の当社グループの業績は、売上高631億19百万円（前期比3.5％増...
#
#                                preprocessingSentence
# 0  当連結会計年度におけるわが国経済は 政府の経済政策や日銀の金融緩和策により 企業業績 雇用・...
# 1  当社グループを取り巻く環境は 実質賃金が伸び悩むなか 消費者の皆様の生活防衛意識の高まりや節...
# 2  このような環境の中 当社グループはきのこ事業を中心として 健康食材である きのこ の研究開発...
# 3  また 平成年に策定いたしました中期経営計画の見直しを行い 市況に左右されない事業ポートフォリ...
# 4  以上の結果 当連結会計年度の当社グループの業績は 売上高億百万円 前期比  増  営業利益億...

# %%
# Mecabで分かち書きする関数
def wakachi(text, select_word_type=['名詞']):
    # MeCabの準備
    tagger = MeCab.Tagger()
    tagger.parse('')
    node = tagger.parseToNode(text)
    word_list = []
    while node:
        word_type = node.feature.split(',')[0]
        if word_type in select_word_type:  # 指定した品詞のみ処理
            if word_type == '名詞':
                word_list.append(node.surface)
            else:
                word_list.append(node.feature.split(",")[6])
        else:
            pass
        node = node.next

    # リストを文字列に変換
    word_chain = ' '.join(word_list)
    if len(word_list)==0:
        'no list!'
    return word_list, word_chain  # リストでまとめた結果とすべてつなげた文字列を返す

# dfでまとめた文章をすべて分かち書き処理する関数
def makeWakachiDf(sentenceDf, col, stop_words, select_word_type=['名詞']):
    word_list_noun_list = []
    word_chain_noun_list = []
    for i, text in tqdm(enumerate(sentenceDf[col])):  # 指定した列にある文章を1行ずつ分かち書き処理
        word_list_noun, word_chain_noun = wakachi(text, select_word_type=select_word_type)
        word_list_noun = [w for w in word_list_noun if w not in stop_words]  # ストップワードも設定
        if len(word_list_noun)==0:  # 分かち書きとストップワード除去で何もなかった場合何もない結果を追加
            word_list_noun_list.append([])
            word_chain_noun_list.append('')
            continue
        word_list_noun_list.append(word_list_noun)  #分かち書きとストップワード除去の結果を追加
        word_chain_noun_list.append(word_chain_noun)  #分かち書きとストップワード除去の結果を追加
    return word_list_noun_list, word_chain_noun_list  # リストでまとめた結果とすべてつなげた文字列をリストにまとめて返す

# %%
# ストップワードを定義
with open('bert_test/Japanese.txt', 'r', encoding='utf-8') as f:
    stop_words = [w.strip() for w in f]
    stop_words = stop_words+['する', 'なる', 'いる', 'ある']
    stop_words = set(stop_words)
print(list(stop_words)[:10])
# Out:
# ['あちら', '', '全部', '例', '力', '度', 'ふく', '区', 'さらい', 'みなさん']

# %%
# dfでまとめた文章をすべて分かち書き処理
word_list_noun_list, word_chain_noun_list = makeWakachiDf(sentenceDf, 'preprocessingSentence'
                                                          , stop_words, select_word_type=['名詞'])  # 今回は名詞だけ
# 分かち書き処理の結果をdfに追加
sentenceDf['wakachiSentenceList'] = word_list_noun_list
sentenceDf['wakachiSentenceChain'] = word_chain_noun_list
# 分かち書き処理の結果、空のリストの行を削除
sentenceDf = sentenceDf[sentenceDf['wakachiSentenceList'].apply(lambda x:len(x)>0)].reset_index(drop=True)
display(sentenceDf.head())
# Out:
# 6119it [00:26, 227.03it/s]
#    sentence_id                                           sentence  \
# 0            0  当連結会計年度におけるわが国経済は、政府の経済政策や日銀の金融緩和策により、企業業績、雇用・...
# 1            1  当社グループを取り巻く環境は、実質賃金が伸び悩むなか、消費者の皆様の生活防衛意識の高まりや節...
# 2            2  このような環境の中、当社グループはきのこ事業を中心として、健康食材である「きのこ」の研究開発...
# 3            3  また、平成26年に策定いたしました中期経営計画の見直しを行い、市況に左右されない事業ポートフ...
# 4            4  以上の結果、当連結会計年度の当社グループの業績は、売上高631億19百万円（前期比3.5％増...
#
#                                preprocessingSentence  \
# 0  当連結会計年度におけるわが国経済は 政府の経済政策や日銀の金融緩和策により 企業業績 雇用・...
# 1  当社グループを取り巻く環境は 実質賃金が伸び悩むなか 消費者の皆様の生活防衛意識の高まりや節...
# 2  このような環境の中 当社グループはきのこ事業を中心として 健康食材である きのこ の研究開発...
# 3  また 平成年に策定いたしました中期経営計画の見直しを行い 市況に左右されない事業ポートフォリ...
# 4  以上の結果 当連結会計年度の当社グループの業績は 売上高億百万円 前期比  増  営業利益億...
#
#                                  wakachiSentenceList  \
# 0  [連結会計, 年度, わが国, 経済, 政府, 経済政策, 日銀, 金融緩和, 策, 企業業...
# 1  [当社, グループ, 環境, 実質賃金, 消費, 皆様, 生活防衛, 意識, 高まり, 節約...
# 2  [環境, 当社, グループ, きのこ, 事業, 中心, 健康, 食材, きのこ, 研究開発,...
# 3  [平成, 策定, 中期経営計画, 見直し, 市況, 左右, 事業, ポートフォリオ, 構築,...
# 4  [結果, 連結会計, 年度, 当社, グループ, 業績, 売上高, 前期比, 増, 営業利益...
#
#                                 wakachiSentenceChain
# 0  連結会計 年度 わが国 経済 政府 経済政策 日銀 金融緩和 策 企業業績 雇用 所得 環境...
# 1  当社 グループ 環境 実質賃金 なか 消費 者 皆様 生活防衛 意識 高まり 節約志向 個人...
# 2  よう 環境 中 当社 グループ きのこ 事業 中心 健康 食材 きのこ 研究開発 生産 販売...
# 3  平成 年 策定 中期経営計画 見直し 市況 左右 事業 ポートフォリオ 構築 活動 推進 健...
# 4  以上 結果 連結会計 年度 当社 グループ 業績 売上高 億 百 万 円 前期比 増 営業利...

# %% [markdown]
# # Word2Vecの学習

# %%
# %%time
# gensimでWord2Vecモデル作成
# vector_size : output dimention
# min_count : この値以下の出現回数の単語を無視
# window : 対象単語を中心とした前後の単語数
# epochs : epochs数
# sg : skip-gramを使うかどうか 0:CBOW 1:skip-gram
wv_model = word2vec.Word2Vec(sentenceDf['wakachiSentenceList'].to_numpy()
                             , vector_size=200, min_count=5, window=5, sg=1)
# モデルの学習
wv_model.train(sentenceDf['wakachiSentenceList'].to_numpy(), total_examples=wv_model.corpus_count, epochs=20)
vocab = wv_model.wv.index_to_key  # 分かち書きした語彙
print(vocab[:5])
# Out:
# ['事業', '年度', '連結会計', '百万円', '売上高']
# Wall time: 3.22 s

# %% [markdown]
# # BERTの学習(MaskedLM)

# %%
# 東北大学の学習済みTokenizerを使用する
model_name = 'cl-tohoku/bert-base-japanese-whole-word-masking'
# 東北大学の学習済みTokenizer読み込み
tokenizerOrg = BertJapaneseTokenizer.from_pretrained(model_name)
text_example = "当連結会計年度におけるわが国経済は 政府の経済政策や日銀の金融緩和策により 企業業績 雇用・所得環境は改善"
print(len(tokenizerOrg))  # トークンの数
print(tokenizerOrg.tokenize(text_example))  # 例文をトークンに分割
# chABSA-datasetをMecabで分けた結果の語彙をtokenizerに追加
addVocab = ' '.join(sentenceDf['wakachiSentenceChain'].to_list()).split(' ')
tokenizerOrg.add_tokens(addVocab)
print(len(tokenizerOrg))  # トークンの数
print(tokenizerOrg.tokenize(text_example))  # 例文をトークンに分割
tokenizerOrg.save_pretrained("bert_test/qiita_bert_token/")  # Save
# 注意：tokenizerOrg.vocab_sizeはOriginalのサイズを出力し、追加しても変わらないので注意（issue#4486）
# Out:
# 32000
# ['当', '連結', '会計', '年度', 'における', 'わが', '##国', '経済', 'は', '政府', 'の', '経済', '政策', 'や', '日銀', 'の', '金融', '緩和', '策', 'により', '企業', '業績', '雇用', '・', '所得', '環境', 'は', '改善']
# 37138
# ['当', '連結会計', '年度', 'における', 'わが国', '経済', 'は', '政府', 'の', '経済政策', 'や', '日銀', 'の', '金融緩和', '策', 'により', '企業業績', '雇用', '・', '所得', '環境', 'は', '改善']
# ('bert_test/qiita_bert_token/tokenizer_config.json',
#  'bert_test/qiita_bert_token/special_tokens_map.json',
#  'bert_test/qiita_bert_token/vocab.txt',
#  'bert_test/qiita_bert_token/added_tokens.json')

# %%
# モデルの構造を定義するBertConfigを設定
config = BertConfig(vocab_size=len(tokenizerOrg))  # 語彙数だけ設定してあとはデフォルト
print(config)
bertModel = BertForMaskedLM(config)  # MaskedLMタスクで学習
# Out:
# BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 37138
# }

# %%
# DataCollatorはいくつかの処理（パディングなど）を適用する
# DataCollatorForLanguageModelingなどは、形成されたバッチにランダムデータ拡張（ランダムマスキングなど）も適用
# ランダムに選ばれた15%のトークンを[MASK]という特殊トークンに置き換え、[MASK]にもともとあったトークンを予測するタスクで学習
# ただし、右のような確率でマスクする：80% MASK, 10% ランダムに他のトークンに, 10% 何も変更しない.
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizerOrg, mlm=True, mlm_probability=0.15)

# %%
# 学習するテキストをtxtファイルで保存しておく
display(sentenceDf['preprocessingSentence'].head(2))
sentenceDf['preprocessingSentence'].to_csv('bert_test/preprocessingSentence.txt', index=False, header=False)
# Out:
# 0    当連結会計年度におけるわが国経済は 政府の経済政策や日銀の金融緩和策により 企業業績 雇用・...
# 1    当社グループを取り巻く環境は 実質賃金が伸び悩むなか 消費者の皆様の生活防衛意識の高まりや節...
# Name: preprocessingSentence, dtype: object

# %%
# 1文書の最大長を定義
#with open('bert_test/preprocessingSentence.txt', encoding='utf-8') as f:
#    max_length = np.max([len(tokenizerOrg(line)['input_ids']) for line in f])
max_length = np.max([len(line) for line in tokenizerOrg(list(sentenceDf['preprocessingSentence'].to_numpy()))['input_ids']])
print('max length', max_length)
# Out:
# max length 166

# %%
# MaskedLMタスクで学習させるためのdatasetに加工
textDataset = LineByLineTextDataset(tokenizer=tokenizerOrg  # 使用するtokenizer
                                , file_path='bert_test/preprocessingSentence.txt'  # 学習するテキスト
                                , block_size=max_length, # tokenizerのmax_length
                               )
# Out:
# C:\Users\yusuke.kiridoshi\AppData\Local\pypoetry\Cache\virtualenvs\kiri-rM9h93NJ-py3.7\lib\site-packages\transformers\data\datasets\language_modeling.py:125: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/language-modeling/run_mlm.py
#   FutureWarning,

# %%
# 事前学習に関するパラメータを設定
trainingArguments = TrainingArguments(output_dir= 'bert_test/'
                                      , overwrite_output_dir=True
                                      , num_train_epochs=3  # CPUなので少なめ
                                      #, per_device_train_batch_size=32
                                      #, save_steps=500
                                      #, save_strategy='steps'
                                      #, do_eval=True  # 評価データを用意する必要がある
                                      #, eval_steps=500  # 評価データを用意する必要がある
                                      #, evaluation_strategy='steps'  # 評価データを用意する必要がある
                                      #, load_best_model_at_end=True
                                      , logging_dir='bert_test/qiita_bert/runs/'
                                      , save_total_limit=3
                                      , prediction_loss_only=True
                                      , learning_rate=1e-3,  # CPUなので大きめ
                                     )
# 事前学習するインスタンス作成
trainer = Trainer(model=bertModel
                  , args=trainingArguments
                  , data_collator=data_collator
                  , train_dataset=textDataset
                 )

# %%
# %%time
trainer.train()
trainer.save_model('bert_test/qiita_bert/')
# 3h 25min 33s

# %%
# %load_ext tensorboard
# %tensorboard --logdir 'bert_test/qiita_bert/runs/' --host=127.0.0.1
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-1a3d1fa7bc8960a9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1a3d1fa7bc8960a9");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# 評価データを入れる場合
'''
# 学習するテキストをtxtファイルで保存しておく
display(sentenceDf['preprocessingSentence'].head(2))
sentenceDf['preprocessingSentence'][:int(sentenceDf['preprocessingSentence'].shape[0]*0.8)].to_csv('bert_test/train.txt', index=False, header=False)
sentenceDf['preprocessingSentence'][int(sentenceDf['preprocessingSentence'].shape[0]*0.8):].to_csv('bert_test/valid.txt', index=False, header=False)
# MaskedLMタスクで学習させるためのdatasetに加工
textDatasetTrain = LineByLineTextDataset(tokenizer=tokenizerOrg  # 使用するtokenizer
                                , file_path='bert_test/train.txt'  # 学習するテキスト
                                , block_size=max_length, # tokenizerのmax_length
                               )
# MaskedLMタスクで学習させるためのdatasetに加工
textDatasetValid = LineByLineTextDataset(tokenizer=tokenizerOrg  # 使用するtokenizer
                                , file_path='bert_test/valid.txt'  # 学習するテキスト
                                , block_size=max_length, # tokenizerのmax_length
                               )

# 事前学習に関するパラメータを設定
trainingArguments = TrainingArguments(output_dir= 'bert_test/'
                                      , overwrite_output_dir=True
                                      , num_train_epochs=10  # CPUなので少なめ
                                      , per_device_train_batch_size=64
                                      , save_steps=200
                                      , save_strategy='steps'
                                      , do_eval=True  # 評価データを用意する必要がある
                                      , eval_steps=200  # 評価データを用意する必要がある
                                      , evaluation_strategy='steps'  # 評価データを用意する必要がある
                                      , load_best_model_at_end=True  # 評価データを用意する必要がある
                                      , logging_dir='bert_test/qiita_bert/runs/'
                                      , save_total_limit=3
                                      , prediction_loss_only=True
                                      , learning_rate=1e-3,  # CPUなので大きめ
                                     )
# 事前学習するインスタンス作成
trainer = Trainer(model=bertModel
                  , args=trainingArguments
                  , data_collator=data_collator
                  , train_dataset=textDatasetTrain
                  , eval_dataset=textDatasetValid
                 )
trainer.train()
trainer.save_model('bert_test/qiita_bert/')
'''

# %%
# 保存したBERTモデルを読み込み
bertModel = BertForMaskedLM.from_pretrained('bert_test/qiita_bert/')
# Out:
# loading configuration file bert_test/qiita_bert/config.json
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 37138
# }
#
# loading weights file bert_test/qiita_bert/pytorch_model.bin
# All model checkpoint weights were used when initializing BertForMaskedLM.
#
# All the weights of BertForMaskedLM were initialized from the model checkpoint at bert_test/qiita_bert/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForMaskedLM for predictions without further training.

# %%
# 前処理済みの文章をtokenizerでidに変換
encoded = tokenizerOrg.batch_encode_plus(sentenceDf['preprocessingSentence'].to_list()
                                         , padding=True
                                         , add_special_tokens=True)  # [CLS]のようなspecial tokenも含む
print(encoded.keys())
print(len(encoded['input_ids'][0]))  # input_idsの1文書の長さ
# BERTトークンID列を抽出
input_ids = torch.tensor(encoded['input_ids'])[:,:]
print(input_ids.shape)  # input_idsの型 文書数×1文書の長さ
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# 166
# torch.Size([6099, 166])

# %%
# %%time
# 分散表現抽出
# 一気に処理するとMemory errorになるのでFor文で1行づつ抽出
last_hidden_states = torch.Tensor()
for inid in tqdm(input_ids[:]):
    bertModel.eval()
    with torch.no_grad():  # 勾配計算なし
        # 単語ベクトルを計算
        outputs = bertModel(inid.reshape(1,-1), output_hidden_states=True)  # 隠れ層の出力もさせる
    last_hidden_states = torch.cat((last_hidden_states, outputs['hidden_states'][-1]))  # 最後の隠れ層ベクトルを抽出
print(last_hidden_states.shape)
# 1h 36min 21s
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 6099/6099 [1:35:12<00:00,  1.07it/s]
# torch.Size([6099, 166, 768])
# Wall time: 1h 35min 12s

# %%
# 最後の隠れ層ベクトルsave
torch.save(last_hidden_states, 'bert_test/last_hidden_states01.pt')
# input_idsもsave
with open("bert_test/encoded01.pkl", "wb") as tf:
    pickle.dump(encoded, tf)
# tokenizersave
tokenizerOrg.save_pretrained('bert_test/tokenizer01')

# %% [markdown]
# # Word2Vec学習済みモデル

# %%
# %%time
# Wikipediaで学習されたモデルをLoad
model_dir = 'bert_test/entity_vector/entity_vector.model.bin'
wv_modelPre = KeyedVectors.load_word2vec_format(model_dir, binary=True)
index2wordPre = wv_modelPre.index_to_key  # Wikipediaの語彙数
# Out:
# Wall time: 6.91 s

# %% [markdown]
# # BERTの学習済みモデル

# %%
# 東北大学の学習済みmodelを使用する
model_name = 'cl-tohoku/bert-base-japanese-whole-word-masking'
# トークナイザーの読み込み
tokenizerPre = BertJapaneseTokenizer.from_pretrained(model_name)
# 学習済みモデルの読み込み
bertModelPre = BertModel.from_pretrained(model_name)
# Out:
# loading file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/vocab.txt from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\15164357d71cd32532e56c1d7c2757141326ae17c53e2277bc417cc7c21da6ea.a7378a0cbee5cff668832a776d72b97a25479604fe9564d5595897f75049e7f4
# loading file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/tokenizer_config.json from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\0e46f722799f19c3f0c53172545108a4b31847d3b9a2d5b100759f6673bd667b.08ae4e4044742b9cc7172698caf1da2524f5597ff8cf848114dd0b730cc44bdc
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading weights file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/pytorch_model.bin from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\cabd9bbd81093f4c494a02e34eb57e405b7564db216404108c8e8caf10ede4fa.464b54997e35e3cc3223ba6d7f0abdaeb7be5b7648f275f57d839ee0f95611fb
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of BertModel were initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertModel for predictions without further training.

# %%
# 東北大学の学習済みTokenizerで分かち書き
encoded = tokenizerPre.batch_encode_plus(sentenceDf['preprocessingSentence'].to_list(), padding=True, add_special_tokens=True)
print(encoded.keys())
print(len(encoded['input_ids'][0]))  # input_idsの1文書の長さ
# 学習済みBERTトークンID列を抽出
input_ids = torch.tensor(encoded['input_ids'])[:,:]
print(input_ids.shape)  # input_idsの型 文書数×1文書の長さ
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# 258
# torch.Size([6099, 258])

# %%
# %%time
# 分散表現抽出
# 一気に処理するとMemory errorになるのでFor文で1行づつ抽出
last_hidden_statesPre = torch.Tensor()
for inid in tqdm(input_ids[:]):
    with torch.no_grad():  # 勾配計算なし
        # 単語ベクトルを計算
        outputs = bertModelPre(inid.reshape(1,-1), output_hidden_states=True)
    last_hidden_statesPre = torch.cat((last_hidden_statesPre, outputs.last_hidden_state))
# 最終層の隠れ状態ベクトルを取得
print(last_hidden_statesPre.shape)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 6099/6099 [2:10:46<00:00,  1.29s/it]
# torch.Size([6099, 258, 768])
# Wall time: 2h 10min 46s

# %%
# 最後の隠れ層ベクトルsave
torch.save(last_hidden_statesPre, 'bert_test/last_hidden_states02.pt')

# %% [markdown]
# # WordNetの同義語取得

# %%
'''
「8ケタの数字+"-(半角ハイフン)"+アルファベット」で表されています。アルファベットは品詞を表していて、
それぞれ
  n= 名詞
  v= 動詞
  a= 形容詞
  r= 副詞
  
同義語(synonym)
その概念を言い表すのに使用される語です。
英語のものは英語ワードネットのもので、日本語のものは複数の他言語ワードネットと対日辞書を用いて作成しました。
その後ある程度までは人手で修正しましたが、まだチェックしきれていないものも残っており、誤りが含まれている、
あるいは含まれるべきものが含まれていないという場合もございます。 同義語の扱いについての詳しい話はこちら。

関連synsetとのリンク
Hype　Hypernym　上位語　当該synsetが相手synsetに包含される　"canis familiaris"(02084071-n)は"domestic animal"(01317541-n)と"canid"(02083346-n)に包含される
Hypo　Hyponym　下位語　当該synsetが相手synsetを包含する　"canis familiaris"(02084071-n)は"toy canis familiaris"(02085374-n),"mutt"(02084861-n),"pooch"(02084732-n),...を包含する
Mprt　Meronyms --- Part　被構成要素(部分)　当該synsetが相手synsetという部分によって構成される　"canis familiaris"(02084071-n)は"flag"(02158846-n)を一部分として持つ
Hprt　Holonyms --- Part　構成要素(部分)　当該synsetが部分として相手synsetを構成する　"flag"(02158846-n)は"canis familiaris"(02084071-n)や"cervid"(02430045-n)の一部分である
Hmem　Holonyms --- Member　構成要素(構成員)　当該synsetが相手synsetの構成員である　"canis familiaris"(02084071-n)は"02083863-n"(canis)や"pack"(07994941-n)の構成員である
Mmem　Meronyms --- Member　被構成要素(構成員)　当該synsetが相手synsetという構成員によって構成される　"canis"(02083863-n)は"canis familiaris"(02084071-n)や" jackal"(02115096-n)、"wolf"(02114100-n)を構成員として持つ
Msub　Meronyms --- Substance　被構成要素(物質・材料)　当該synsetが相手synsetという物質or材料によって構成される　"ozone"(14972807-n)は"atomic number 8"(14648100-n)という物質を構成要素として持つ
Hsub　Holonyms --- Substance　構成要素(物質・材料)　当該synsetが相手synsetを構成する物質or材料である　"atomic number 8"(14648100-n)は"ozone"(14972807-n)や"water"(14845743-n)、"air"(14841267-n)を構成する物質である
Dmnc　Domain --- Category　被包含領域(カテゴリ)　当該synsetが相手synsetのカテゴリに属する　"comet"(09251407-n)は"astronomy"(06095022-n)のカテゴリに属する
Dmtc　In Domain --- Category　包含領域(カテゴリ)　当該synseが相手synsetが属するカテゴリである　"astronomy"(06095022-n)というカテゴリには"uprise"(01970348-v)や"absolute magnitude"(05090979-n)が属している
Dmnu　Domain --- Usage　被包含領域(語法)　当該synsetの用法が相手synsetの領域に限られる　"jean"(03594734-n)の用法は"plural form"(06295235-n)に限定される
Dmtu　In Domain --- Usage　包含領域(語法)　当該synsetの領域が相手synsetの用法を規定する　"plural form"(06295235-n)は"jean"(03594734-n)の用法を規定する
Dmnr　Domain --- Region　被包含領域(地域)　当該synsetが相手synsetの地域に属するものである　"sake"(07891433-n)は"nippon"(08921850-n)という地域に属している
Dmtr　In Domain --- Region　包含領域(地域)　当該synsetが相手synsetの属する地域である　"nippon"(08921850-n)は"sake"(07891433-n)の属する地域である
Inst　Instances　例　当該synsetは相手synsetの例である　"seiji ozawa"(11219502-n)は"director"(09952539-n)の例である
Hasi　Has Instance　例あり　当該synsetは相手synsetを例として持つ　"director"(09952539-n)は"seiji ozawa"(11219502-n)を例に持つ
Enta　Entails　含意　当該synsetを行う場合、必ず相手synsetも行っている　"fleece"(02319050-v)を行う場合、必ず"charge"(02320374-v)も行っている
Caus　Causes　引き起こし　当該synsetを行うと、相手synsetを引き起こす　"project"(02138075-v)を行うと、"appear"(00422090-v)を引き起こす
Also　See also　関連　当該synsetと相手synsetとの間に何らかの関連がある　"white"(00393105-a)は"light"(00408660-a)との間に何らかの関連がある
Attr　Attributes　属性　(a=形容詞のsynsetから見て)当該synsetが相手synsetという属性を表す際に使われる　"white"(00393105-a)は"value"(04979425-n)という属性を表す際に使われる
(n=名詞のsynsetから見て)当該synsetという属性を表す際に相手synsetを使う　"value"(04979425-n)という属性を表すのに"white"(00393105-a)を使う
Sim　Similar to　近似　当該synsetは表す意味が相手synsetと近似している　"white"(00393105-a)は意味が"albescent"(00393422-a)と近似している
'''

# %%
# WordNet DBと接続
conn = sqlite3.connect("bert_test/wnjpn.db")

# %%
# Table一覧取得
tableDf=pd.read_sql_query(
    """
    select
        name
    from
        sqlite_master
    where
        type='table'
    """
    , conn
)
display(tableDf)
# Out:
#           name
# 0      pos_def
# 1     link_def
# 2   synset_def
# 3    synset_ex
# 4       synset
# 5      synlink
# 6     ancestor
# 7        sense
# 8         word
# 9      variant
# 10       xlink

# %%
# wordidと単語一覧Table
# 日本語に限定
wordDf=pd.read_sql_query(
    """
    select
        *
    from
        word
    """
    , conn
)
wordDf = wordDf[wordDf['lang']=='jpn']
display(wordDf.head())
# Out:
#         wordid lang     lemma  pron pos
# 155287  155288  jpn        頭金  None   n
# 155288  155289  jpn  どうにかこうにか  None   r
# 155289  155290  jpn        大砲  None   n
# 155290  155291  jpn      スチーム  None   n
# 155291  155292  jpn      溢れでる  None   v

# %%
# 日本語の概念(上位語、被包含領域など)を表すsynsetとwordidを紐づけるためのTable
senseDf=pd.read_sql_query(
    """
    select
        *
    from
        sense
    """
    , conn
)
senseDf = senseDf[senseDf['lang']=='jpn']
display(senseDf.head())
# Out:
#             synset  wordid lang  rank  lexid  freq    src
# 206941  13349834-n  155288  jpn  None    NaN   NaN   hand
# 206942  00151040-r  155289  jpn  None    NaN   NaN   hand
# 206943  02950632-n  155290  jpn  None    NaN   NaN  multi
# 206944  02746365-n  155290  jpn  None    NaN   NaN   hand
# 206945  02462828-n  155290  jpn  None    NaN   NaN  multi

# %%
# synsetの一覧Table
synsetDf=pd.read_sql_query(
    """
    select
        *
    from
        synset
    """
    , conn
)
display(synsetDf.head())
# Out:
#        synset pos       name    src
# 0  07125096-n   n  expletive  eng30
# 1  07126228-n   n  expletive  eng30
# 2  14123044-n   n    measles  eng30
# 3  08030185-n   n    contras  eng30
# 4  09902017-n   n   beef_man  eng30

# %%
# 日本語の概念の関係の定義Table
synlinkDf=pd.read_sql_query(
    """
    select
        *
    from
        synlink
    """
    , conn
)
display(synlinkDf.head())
# Out:
#       synset1     synset2  link    src
# 0  07125096-n  07128527-n  hype  eng30
# 1  07126228-n  07109847-n  hype  eng30
# 2  14123044-n  14122235-n  hype  eng30
# 3  14123044-n  14123259-n  hypo  eng30
# 4  08030185-n  08197895-n  inst  eng30

# %%
# 概念の例文の定義Table
synset_defDf=pd.read_sql_query(
    """
    select
        *
    from
        synset_def
    """
    , conn
)
synset_defDf = synset_defDf[synset_defDf['lang']=='jpn']
display(synset_defDf.head())
# Out:
#             synset lang                                def sid
# 118530  01785341-a  jpn  懇願によって静められない、なだめられない、または、動かされないさま   0
# 118532  11820323-n  jpn                  南アフリカ産の茎のない多肉植物の属   0
# 118534  04239436-n  jpn                      傷ついた前腕を支持する包帯   0
# 118536  04239436-n  jpn      首のあたりから掛かっている布の広い三角形の部分からなるもの   1
# 118538  11427067-n  jpn                     太陽の大気圏の最も外側の領域   0

# %%
# 各テーブルを紐づける
# 各wordidにsynsetを追加
wordMaster = pd.merge(wordDf[['wordid', 'lemma', 'pos']], senseDf[['wordid', 'synset']], on=['wordid'], how='left')
display(wordMaster.head(1))
# 各synsetにnameを追加
wordMaster = pd.merge(wordMaster, synsetDf[['synset', 'name']], on=['synset'], how='left')
display(wordMaster.head(1))
# 各synsetに対応するwordidを追加
wordMaster = pd.merge(wordMaster, senseDf[['wordid', 'synset']].rename(columns={'wordid':'sameWordid'}), on=['synset'], how='left')
display(wordMaster.head(1))
# 各synsetに対応するwordidに対応するlemmaを追加
wordMaster = pd.merge(wordMaster
                      , wordDf[['wordid', 'lemma', 'pos']].rename(columns={'wordid':'sameWordid', 'lemma':'sameLemma', 'pos':'samePos'})
                      , on=['sameWordid'], how='left')
display(wordMaster.head(1))
# もともとのwordidと各synsetに対応するwordidが同じ行は削除
wordMaster = wordMaster[wordMaster['wordid']!=wordMaster['sameWordid']]
display(wordMaster.head())
# Out:
#    wordid lemma pos      synset
# 0  155288    頭金   n  13349834-n
#    wordid lemma pos      synset     name
# 0  155288    頭金   n  13349834-n  deposit
#    wordid lemma pos      synset     name  sameWordid
# 0  155288    頭金   n  13349834-n  deposit      155288
#    wordid lemma pos      synset     name  sameWordid sameLemma samePos
# 0  155288    頭金   n  13349834-n  deposit      155288        頭金       n
#    wordid lemma pos      synset     name  sameWordid sameLemma samePos
# 1  155288    頭金   n  13349834-n  deposit      161058     デポジット       n
# 2  155288    頭金   n  13349834-n  deposit      165962      手付け金       n
# 3  155288    頭金   n  13349834-n  deposit      183741        内金       n
# 4  155288    頭金   n  13349834-n  deposit      194952       証拠金       n
# 5  155288    頭金   n  13349834-n  deposit      247271        手金       n

# %%
# こっちでも可
wordMaster =pd.read_sql_query(
    """
    select
        wordid
        , lemma
        , pos
        , lang
        , synset
        , name
        , t_merge02.sameWordid as sameWordid
        , sameLemma
        , samePos
    from
        (
        select
            t_merge01.wordid as wordid
            , lemma
            , pos
            , lang
            , t_merge01.synset as synset
            , name
            , sameWordid
        from
            (
            select
                t_word.wordid as wordid
                , lemma
                , pos
                , lang
                , synset
            from
                (
                select
                    wordid
                    , lemma
                    , pos
                    , lang
                from
                    word
                where
                    lang='jpn'
                ) as t_word
            left join
                (
                select
                    wordid
                    , synset
                from
                    sense
                where
                    lang='jpn'
                ) as t_sense
            on
                t_word.wordid = t_sense.wordid
            ) as t_merge01
        left join
            (
            select
                synset
                , name
            from
                synset
            ) as t_synset
        on
            t_merge01.synset = t_synset.synset
        left join
            (
            select
                wordid as sameWordid
                , synset
            from
                sense
            where
                lang='jpn'
            ) as t_sense02
        on
            t_merge01.synset = t_sense02.synset
        ) as t_merge02
    left join
        (
        select
            wordid as sameWordid
            , lemma as sameLemma
            , pos as samePos
        from
            word
        where
            lang='jpn'
        ) as t_word02
    on
        t_merge02.sameWordid = t_word02.sameWordid
    where
        wordid<>t_merge02.sameWordid
    """
    , conn
)
display(wordMaster.head())

# %% [markdown]
# # 同義語の抽出の評価

# %% [markdown]
# ## chABSA-dataset Word2Vec評価

# %%
# Word2Vec学習時に定義した語彙のリスト vocabに出てくる単語を評価対象にする
# 同義語抽出評価

sameWordsCnt = 0  # 初期値 同義語の数
# vocabに出てくる単語に限定
wordMasterPart = wordMaster[(wordMaster['lemma'].isin(list(vocab)))&(wordMaster['sameLemma'].isin(list(vocab)))]
# vocabに出てくる単語に限定した後のWordNetの同義語の数
allSameWordsCnt = wordMasterPart[['lemma', 'sameLemma']].drop_duplicates().shape[0]
print('限定したWordNetの語彙数', wordMasterPart['lemma'].unique().shape[0])
print('限定したWordNetの単語にあるすべての同義語の数', allSameWordsCnt, '\n')
# 限定したWordNetの単語ごとの同義語についてモデルがいくつ同じ同義語を抽出できているかカウントする
for i, tango in enumerate(wordMasterPart['lemma'].unique()):
    # tango=WordNetの単語1つずつループ
    # tangoに最も似ている単語Top5をdfにまとめる
    w2vCosDf = pd.DataFrame(wv_model.wv.most_similar(tango), columns=['sameLemma', 'cos'])
    w2vCosDf.insert(0, 'lemma', tango)
    # 限定したWordNetと紐づける
    mergeDf = pd.merge(wordMasterPart[wordMasterPart['lemma']==tango][['lemma', 'sameLemma']].drop_duplicates()
                       , w2vCosDf, on=['lemma', 'sameLemma'], how='inner')
    # 紐づけたdfの結果
    if len(mergeDf) > 0:
        print(tango)
        display(mergeDf)
        print('===============', '\n')
    sameWordsCnt += len(mergeDf)  # 紐づけられた同義語の数を足す
# 最終的な正解数
print('正解数', str(sameWordsCnt), '/', allSameWordsCnt)
# Out:
# 限定したWordNetの語彙数 787
# 限定したWordNetの単語にあるすべての同義語の数 2810
#
# 創造
#   lemma sameLemma       cos
# 0    創造        創出  0.804618
# ===============
#
# 取扱
#   lemma sameLemma       cos
# 0    取扱       取扱い  0.696676
# ===============
#
# 船舶
#   lemma sameLemma       cos
# 0    船舶         船  0.706125
# ===============
#
# リスク
#   lemma sameLemma       cos
# 0   リスク        危険  0.678124
# ===============
#
# プラン
#   lemma sameLemma       cos
# 0   プラン     プログラム  0.818895
# ===============
#
# 量
#   lemma sameLemma       cos
# 0     量        物量  0.496092
# ===============
#
# 成長
#   lemma sameLemma    cos
# 0    成長        発展  0.536
# ===============
#
# 予想
#   lemma sameLemma       cos
# 0    予想        予断  0.636117
# ===============
#
# ライン
#   lemma sameLemma       cos
# 0   ライン        道路  0.678628
# ===============
#
# 医薬
#   lemma sameLemma       cos
# 0    医薬        治療  0.667915
# ===============
#
# 地域
#   lemma sameLemma       cos
# 0    地域        地方  0.477052
# ===============
#
# 提携
#   lemma sameLemma       cos
# 0    提携        連携  0.673816
# ===============
#
# 安全
#   lemma sameLemma       cos
# 0    安全        安心  0.835572
# ===============
#
# 連携
#   lemma sameLemma       cos
# 0    連携        提携  0.673816
# ===============
#
# 運搬
#   lemma sameLemma       cos
# 0    運搬        搬送  0.826465
# ===============
#
# 原料
#   lemma sameLemma       cos
# 0    原料       原材料  0.678626
# ===============
#
# 比較
#   lemma sameLemma       cos
# 0    比較        対比  0.657077
# ===============
#
# 詳細
#   lemma sameLemma       cos
# 0    詳細        事項  0.771388
# ===============
#
# 米国
#   lemma sameLemma       cos
# 0    米国      アメリカ  0.643579
# ===============
#
# 減少
#   lemma sameLemma      cos
# 0    減少         減  0.60085
# ===============
#
# 構築
#   lemma sameLemma      cos
# 0    構築        確立  0.64852
# ===============
#
# 総合
#   lemma sameLemma       cos
# 0    総合        統合  0.608022
# ===============
#
# 安定
#   lemma sameLemma       cos
# 0    安定       安定化  0.499498
# ===============
#
# 構造
#   lemma sameLemma       cos
# 0    構造        組織  0.537185
# ===============
#
# 牽引
#   lemma sameLemma       cos
# 0    牽引        主導  0.634267
# ===============
#
# プログラム
#    lemma sameLemma       cos
# 0  プログラム       プラン  0.818895
# ===============
#
# 原材料
#   lemma sameLemma       cos
# 0   原材料        原料  0.678626
# ===============
#
# 閉鎖
#   lemma sameLemma       cos
# 0    閉鎖        閉店  0.820683
# ===============
#
# 広告
#   lemma sameLemma       cos
# 0    広告        宣伝  0.801979
# ===============
#
# 縮小
#   lemma sameLemma       cos
# 0    縮小      引き下げ  0.601462
# ===============
#
# 対比
#   lemma sameLemma       cos
# 0    対比        比較  0.657077
# ===============
#
# 稼働
#   lemma sameLemma       cos
# 0    稼働        稼動  0.611754
# ===============
#
# 創出
#   lemma sameLemma       cos
# 0    創出        創造  0.804618
# ===============
#
# 契約
#   lemma sameLemma       cos
# 0    契約        締結  0.569186
# ===============
#
# 空調設備
#   lemma sameLemma       cos
# 0  空調設備        空調  0.822004
# ===============
#
# 転換
#   lemma sameLemma       cos
# 0    転換      切り替え  0.655898
# ===============
#
# 配当金
#   lemma sameLemma       cos
# 0   配当金        配当  0.772841
# ===============
#
# 取扱い
#   lemma sameLemma       cos
# 0   取扱い        取扱  0.696676
# ===============
#
# 算出
#   lemma sameLemma       cos
# 0    算出        計算  0.791435
# ===============
#
# 搬送
#   lemma sameLemma       cos
# 0    搬送        運搬  0.826465
# ===============
#
# 配当
#   lemma sameLemma       cos
# 0    配当       配当金  0.772841
# ===============
#
# 拡大
#   lemma sameLemma       cos
# 0    拡大        伸長  0.403398
# ===============
#
# 展示
#   lemma sameLemma       cos
# 0    展示        出展  0.878253
# ===============
#
# 競争
#   lemma sameLemma       cos
# 0    競争        競合  0.638988
# ===============
#
# 開設
#   lemma sameLemma       cos
# 0    開設        創業  0.712481
# ===============
#
# 食品
#   lemma sameLemma       cos
# 0    食品        食材  0.681896
# ===============
#
# 公表
#   lemma sameLemma       cos
# 0    公表        告示  0.768777
# ===============
#
# 減額
#   lemma sameLemma       cos
# 0    減額        減損  0.836383
# ===============
#
# 修理
#   lemma sameLemma       cos
# 0    修理        補修  0.750938
# ===============
#
# 管理
#   lemma sameLemma       cos
# 0    管理    マネジメント  0.605311
# ===============
#
# 状況
#   lemma sameLemma       cos
# 0    状況        状態  0.425233
# ===============
#
# メンテナンス
#     lemma sameLemma       cos
# 0  メンテナンス        保守  0.666923
# 1  メンテナンス        補修  0.648121
# ===============
#
# 調整
#   lemma sameLemma       cos
# 0    調整        加減  0.618343
# ===============
#
# 信用
#   lemma sameLemma       cos
# 0    信用        信託  0.737746
# ===============
#
# 協力
#   lemma sameLemma       cos
# 0    協力        協働  0.734249
# ===============
#
# 安心
#   lemma sameLemma       cos
# 0    安心        安全  0.835572
# ===============
#
# 急速
#   lemma sameLemma       cos
# 0    急速        急激  0.673121
# ===============
#
# 保守
#   lemma sameLemma       cos
# 0    保守    メンテナンス  0.666923
# ===============
#
# 原則
#   lemma sameLemma       cos
# 0    原則        規定  0.772618
# ===============
#
# 建物
#   lemma sameLemma       cos
# 0    建物        ビル  0.709929
# ===============
#
# スープ
#   lemma sameLemma       cos
# 0   スープ        つゆ  0.898817
# ===============
#
# 医薬品
#   lemma sameLemma      cos
# 0   医薬品         薬  0.69923
# ===============
#
# 最高
#   lemma sameLemma       cos
# 0    最高       ベスト  0.665903
# ===============
#
# 宣伝
#   lemma sameLemma       cos
# 0    宣伝        広告  0.801979
# ===============
#
# 出展
#   lemma sameLemma       cos
# 0    出展        展示  0.878253
# ===============
#
# 減損
#   lemma sameLemma       cos
# 0    減損        減額  0.836383
# ===============
#
# 時価
#   lemma sameLemma       cos
# 0    時価        勘定  0.810963
# ===============
#
# 低減
#   lemma sameLemma       cos
# 0    低減        削減  0.723499
# ===============
#
# 空調
#   lemma sameLemma       cos
# 0    空調      空調設備  0.822004
# ===============
#
# 道路
#   lemma sameLemma       cos
# 0    道路       ライン  0.678628
# ===============
#
# 機械
#   lemma sameLemma       cos
# 0    機械        器具  0.704621
# ===============
#
# 技術
#   lemma sameLemma       cos
# 0    技術      ノウハウ  0.634468
# ===============
#
# 薬
#   lemma sameLemma      cos
# 0     薬       医薬品  0.69923
# ===============
#
# 閉店
#   lemma sameLemma       cos
# 0    閉店        閉鎖  0.820683
# ===============
#
# 伸長
#   lemma sameLemma       cos
# 0    伸長        伸張  0.617704
# ===============
#
# 算定
#   lemma sameLemma      cos
# 0    算定        計算  0.74013
# ===============
#
# つゆ
#   lemma sameLemma       cos
# 0    つゆ       スープ  0.898817
# ===============
#
# モデル
#   lemma sameLemma       cos
# 0   モデル      フレーム  0.602747
# ===============
#
# 正解数 79 / 2810

# %% [markdown]
# ## chABSA-dataset BERT評価

# %%
# gensimと違って自分で似ている単語を抽出する必要がある
# 分散表現のcos類似度を計算して、最も近い単語Top5を抽出する

# %%
# 最後の隠れ層ベクトルLoad
last_hidden_states = torch.load('bert_test/last_hidden_states01.pt')
# input_idsもLoad
with open("bert_test/encoded01.pkl", "rb") as tf:
    encoded = pickle.load(tf)
input_ids = torch.tensor(encoded.input_ids)

tokenizerOrg = BertJapaneseTokenizer.from_pretrained('bert_test/tokenizer01')
# Out:
# loading file bert_test/tokenizer01\vocab.txt
# loading file bert_test/tokenizer01\added_tokens.json
# loading file bert_test/tokenizer01\special_tokens_map.json
# loading file bert_test/tokenizer01\tokenizer_config.json
# Adding 連結会計 to the vocabulary
# Adding わが国 to the vocabulary
# Adding 経済政策 to the vocabulary
# Adding 金融緩和 to the vocabulary
# Adding 企業業績 to the vocabulary
# Adding 新興国 to the vocabulary
# Adding 欧州連合 to the vocabulary
# Adding eu to the vocabulary
# Adding 新政権 to the vocabulary
# Adding 先行き to the vocabulary
# Adding 実質賃金 to the vocabulary
# Adding 皆様 to the vocabulary
# Adding 生活防衛 to the vocabulary
# Adding 節約志向 to the vocabulary
# Adding 個人消費 to the vocabulary
# Adding 少子高齢化 to the vocabulary
# Adding 人口減少 to the vocabulary
# Adding 社会構造 to the vocabulary
# Adding 企業間 to the vocabulary
# Adding きのこ to the vocabulary
# Adding 研究開発 to the vocabulary
# Adding 事業活動 to the vocabulary
# Adding 中期経営計画 to the vocabulary
# Adding 市況 to the vocabulary
# Adding ポートフォリオ to the vocabulary
# Adding 邁進 to the vocabulary
# Adding 売上高 to the vocabulary
# Adding 前期比 to the vocabulary
# Adding 営業利益 to the vocabulary
# Adding 経常利益 to the vocabulary
# Adding 当期純利益 to the vocabulary
# Adding 生産量 to the vocabulary
# Adding ブナピー to the vocabulary
# Adding ブナシメジ to the vocabulary
# Adding エリンギ to the vocabulary
# Adding マイタケ to the vocabulary
# Adding 概況 to the vocabulary
# Adding 年月日 to the vocabulary
# Adding 広川 to the vocabulary
# Adding 霜降り to the vocabulary
# Adding ひらたけ to the vocabulary
# Adding 品質管理 to the vocabulary
# Adding 付加価値 to the vocabulary
# Adding 薬理 to the vocabulary
# Adding 機能性 to the vocabulary
# Adding シイタケ to the vocabulary
# Adding 研究施設 to the vocabulary
# Adding 営業部門 to the vocabulary
# Adding 鮮度 to the vocabulary
# Adding 営業活動 to the vocabulary
# Adding 菌活 to the vocabulary
# Adding 天候不順 to the vocabulary
# Adding 堅調 to the vocabulary
# Adding 稼働率 to the vocabulary
# Adding 現地法人 to the vocabulary
# Adding 台灣 to the vocabulary
# Adding 股份有限公司 to the vocabulary
# Adding hokto to the vocabulary
# Adding kinoko to the vocabulary
# Adding company to the vocabulary
# Adding アジア系 to the vocabulary
# Adding malaysia to the vocabulary
# Adding sdn to the vocabulary
# Adding bhd to the vocabulary
# Adding 販路 to the vocabulary
# Adding 市場調査 to the vocabulary
# Adding 情報収集 to the vocabulary
# Adding 駐在員事務所 to the vocabulary
# Adding 加工品 to the vocabulary
# Adding 水煮 to the vocabulary
# Adding レトルト食品 to the vocabulary
# Adding 健康食品 to the vocabulary
# Adding 消費者 to the vocabulary
# Adding 直接販売 to the vocabulary
# Adding にも to the vocabulary
# Adding アーデン to the vocabulary
# Adding oem to the vocabulary
# Adding 化成 to the vocabulary
# Adding 包装資材 to the vocabulary
# Adding 効率化 to the vocabulary
# Adding 利益率 to the vocabulary
# Adding 細やか to the vocabulary
# Adding 一昨年 to the vocabulary
# Adding 拡販 to the vocabulary
# Adding 長野市 to the vocabulary
# Adding 豊野 to the vocabulary
# Adding 百万円 to the vocabulary
# Adding eu離脱 to the vocabulary
# Adding 不確実性 to the vocabulary
# Adding 消費マインド to the vocabulary
# Adding 経営環境 to the vocabulary
# Adding 経営成績 to the vocabulary
# Adding 事業所 to the vocabulary
# Adding 特別利益 to the vocabulary
# Adding 増収増益 to the vocabulary
# Adding 前年同期 to the vocabulary
# Adding 冷蔵倉庫 to the vocabulary
# Adding 豊洲新市場 to the vocabulary
# Adding 豊洲 to the vocabulary
# Adding 首都圏 to the vocabulary
# Adding 水産物 to the vocabulary
# Adding 畜産物 to the vocabulary
# Adding 物流センター to the vocabulary
# Adding 入庫 to the vocabulary
# Adding 販管費 to the vocabulary
# Adding 食品事業 to the vocabulary
# Adding 魚卵 to the vocabulary
# Adding 卸売り to the vocabulary
# Adding 納品 to the vocabulary
# Adding リテールサポート to the vocabulary
# Adding 厚焼玉子 to the vocabulary
# Adding 練製品 to the vocabulary
# Adding 販売部門 to the vocabulary
# Adding 買付 to the vocabulary
# Adding 円高基調 to the vocabulary
# Adding 販売力 to the vocabulary
# Adding 取組み to the vocabulary
# Adding 人件費 to the vocabulary
# Adding 取引先 to the vocabulary
# Adding 世界経済 to the vocabulary
# Adding 不透明感 to the vocabulary
# Adding 金融市場 to the vocabulary
# Adding 景気減速 to the vocabulary
# Adding 下支え to the vocabulary
# Adding 非鉄金属 to the vocabulary
# Adding インジウム to the vocabulary
# Adding 為替相場 to the vocabulary
# Adding 上半期 to the vocabulary
# Adding 円高 to the vocabulary
# Adding 下半期 to the vocabulary
# Adding 円安 to the vocabulary
# Adding 箔 to the vocabulary
# Adding スパッタリング to the vocabulary
# Adding 自動車部品 to the vocabulary
# Adding 中計 to the vocabulary
# Adding 四輪車 to the vocabulary
# Adding 排ガス to the vocabulary
# Adding カセロネス to the vocabulary
# Adding 布石 to the vocabulary
# Adding 水力発電 to the vocabulary
# Adding たな卸 to the vocabulary
# Adding 好転 to the vocabulary
# Adding したこと to the vocabulary
# Adding 経常 to the vocabulary
# Adding 損益 to the vocabulary
# Adding 持分法 to the vocabulary
# Adding 減損損失 to the vocabulary
# Adding 特別損益 to the vocabulary
# Adding 投資有価証券 to the vocabulary
# Adding 固定資産 to the vocabulary
# Adding 除却損 to the vocabulary
# Adding 特別損失 to the vocabulary
# Adding 当期純損益 to the vocabulary
# Adding ハイブリッド車 to the vocabulary
# Adding 電気自動車 to the vocabulary
# Adding 環境対応車 to the vocabulary
# Adding リチウムイオン電池 to the vocabulary
# Adding 主要原料 to the vocabulary
# Adding 二輪車 to the vocabulary
# Adding 通期 to the vocabulary
# Adding 低調 to the vocabulary
# Adding mitsui to the vocabulary
# Adding kinzoku to the vocabulary
# Adding components to the vocabulary
# Adding india to the vocabulary
# Adding private to the vocabulary
# Adding limited to the vocabulary
# Adding 月日 to the vocabulary
# Adding 変更し to the vocabulary
# Adding 電子材料 to the vocabulary
# Adding 金属粉 to the vocabulary
# Adding タンタル to the vocabulary
# Adding スマホ to the vocabulary
# Adding 需要拡大 to the vocabulary
# Adding 千t to the vocabulary
# Adding 通信インフラ to the vocabulary
# Adding ito to the vocabulary
# Adding 販売価格 to the vocabulary
# Adding レアメタル to the vocabulary
# Adding 亜鉛メッキ to the vocabulary
# Adding lme to the vocabulary
# Adding ロンドン金属取引所 to the vocabulary
# Adding 金・銀 to the vocabulary
# Adding 国内価格 to the vocabulary
# Adding 微減 to the vocabulary
# Adding 鉛蓄電池 to the vocabulary
# Adding 取替 to the vocabulary
# Adding 国内市場 to the vocabulary
# Adding 軽自動車税 to the vocabulary
# Adding 中国市場 to the vocabulary
# Adding 減税 to the vocabulary
# Adding サイドドアラッチ to the vocabulary
# Adding 原価低減 to the vocabulary
# Adding 現地調達 to the vocabulary
# Adding プラントエンジニア to the vocabulary
# Adding 工事進行基準 to the vocabulary
# Adding 建屋 to the vocabulary
# Adding 減収 to the vocabulary
# Adding 増益 to the vocabulary
# Adding 業況 to the vocabulary
# Adding アンチモン to the vocabulary
# Adding 地金 to the vocabulary
# Adding 四半期 to the vocabulary
# Adding 小幅 to the vocabulary
# Adding 上げ下げ to the vocabulary
# Adding 操業停止 to the vocabulary
# Adding 減産 to the vocabulary
# Adding 円建て to the vocabulary
# Adding 販売増 to the vocabulary
# Adding 建値 to the vocabulary
# Adding 電子部品 to the vocabulary
# Adding 軟磁 to the vocabulary
# Adding 粉末冶金 to the vocabulary
# Adding 熊本地震 to the vocabulary
# Adding 増収 to the vocabulary
# Adding 当期 to the vocabulary
# Adding 設備投資 to the vocabulary
# Adding 持ち直し to the vocabulary
# Adding 資源国 to the vocabulary
# Adding コークス to the vocabulary
# Adding 販売事業 to the vocabulary
# Adding 千百万円 to the vocabulary
# Adding 原材料 to the vocabulary
# Adding コスト削減 to the vocabulary
# Adding 時差 to the vocabulary
# Adding 化工 to the vocabulary
# Adding 連結経常利益 to the vocabulary
# Adding 差益 to the vocabulary
# Adding 法人税等 to the vocabulary
# Adding 当期純損失 to the vocabulary
# Adding 微増 to the vocabulary
# Adding 商権 to the vocabulary
# Adding 競争力 to the vocabulary
# Adding 生産管理 to the vocabulary
# Adding 廃棄物 to the vocabulary
# Adding 傾注 to the vocabulary
# Adding 産業機械 to the vocabulary
# Adding 大規模 to the vocabulary
# Adding 隔年 to the vocabulary
# Adding 今年度 to the vocabulary
# Adding 減収減益 to the vocabulary
# Adding 我が国 to the vocabulary
# Adding スパリゾートハワイアンズ to the vocabulary
# Adding 利用者 to the vocabulary
# Adding 単価 to the vocabulary
# Adding 繰延税金資産 to the vocabulary
# Adding 繰延税金負債 to the vocabulary
# Adding 法人税等調整額 to the vocabulary
# Adding 春休み to the vocabulary
# Adding チームラボ to the vocabulary
# Adding 遊園地 to the vocabulary
# Adding ハワイアンズ to the vocabulary
# Adding ゴールデンウィーク to the vocabulary
# Adding ディノアライブ to the vocabulary
# Adding ファインディングドリー to the vocabulary
# Adding アドベンチャーワールド to the vocabulary
# Adding 洋ラン to the vocabulary
# Adding 冬休み to the vocabulary
# Adding 妖怪ウォッチ to the vocabulary
# Adding カウントダウンイベント to the vocabulary
# Adding よしもと to the vocabulary
# Adding presents to the vocabulary
# Adding 常夏 to the vocabulary
# Adding ファイヤーナイフダンスチーム to the vocabulary
# Adding siva to the vocabulary
# Adding ola to the vocabulary
# Adding シバオラ to the vocabulary
# Adding amata to the vocabulary
# Adding ポリネシアン・サンライトカーニバル to the vocabulary
# Adding aloha to the vocabulary
# Adding rapanui to the vocabulary
# Adding ポリネシアン・グランドステージ to the vocabulary
# Adding ‵ to the vocabulary
# Adding aheo to the vocabulary
# Adding あなたの笑顔 to the vocabulary
# Adding アクアリウム to the vocabulary
# Adding フィッシュゴーランド to the vocabulary
# Adding 話題性 to the vocabulary
# Adding 一巡 to the vocabulary
# Adding 太平洋・島サミット to the vocabulary
# Adding お客様 to the vocabulary
# Adding リニューアルオープン to the vocabulary
# Adding pacific to the vocabulary
# Adding フラガール to the vocabulary
# Adding aaa to the vocabulary
# Adding 西島隆弘 to the vocabulary
# Adding 貸切バス to the vocabulary
# Adding 団体旅行 to the vocabulary
# Adding 福島県沖地震 to the vocabulary
# Adding 電力会社 to the vocabulary
# Adding 運輸業 to the vocabulary
# Adding 輸送量 to the vocabulary
# Adding 減益 to the vocabulary
# Adding 経済状況 to the vocabulary
# Adding 有料老人ホーム to the vocabulary
# Adding 賃料 to the vocabulary
# Adding 建設工事 to the vocabulary
# Adding 舶用 to the vocabulary
# Adding 過年度 to the vocabulary
# Adding 回復の兆し to the vocabulary
# Adding オフィスビル to the vocabulary
# Adding 空室率 to the vocabulary
# Adding 事業部門 to the vocabulary
# Adding 収益力 to the vocabulary
# Adding ハイシリカ to the vocabulary
# Adding 珪石 to the vocabulary
# Adding 棚卸資産 to the vocabulary
# Adding 評価損 to the vocabulary
# Adding 売上原価 to the vocabulary
# Adding 合弁会社 to the vocabulary
# Adding 石灰石 to the vocabulary
# Adding 受けて to the vocabulary
# Adding 造船所 to the vocabulary
# Adding 予熱 to the vocabulary
# Adding 重電 to the vocabulary
# Adding 設備工事 to the vocabulary
# Adding 粗利益率 to the vocabulary
# Adding 建設資材 to the vocabulary
# Adding oa機器 to the vocabulary
# Adding 品等 to the vocabulary
# Adding ライナテックス to the vocabulary
# Adding 米国経済 to the vocabulary
# Adding 経済成長 to the vocabulary
# Adding 鈍化 to the vocabulary
# Adding 不安感 to the vocabulary
# Adding 金融資本 to the vocabulary
# Adding 不透明さ to the vocabulary
# Adding 衣料品 to the vocabulary
# Adding 営業外収益 to the vocabulary
# Adding 受取 to the vocabulary
# Adding 利息 to the vocabulary
# Adding 営業外費用 to the vocabulary
# Adding 為替差損 to the vocabulary
# Adding 支払利息 to the vocabulary
# Adding 連結財務諸表 to the vocabulary
# Adding 注記 to the vocabulary
# Adding 再生可能エネルギー to the vocabulary
# Adding 花菱縫製 to the vocabulary
# Adding ㈱ to the vocabulary
# Adding クリーンサアフェイス to the vocabulary
# Adding のれん to the vocabulary
# Adding 償却 to the vocabulary
# Adding ストロー to the vocabulary
# Adding 復旧作業 to the vocabulary
# Adding 足踏み to the vocabulary
# Adding 建設業界 to the vocabulary
# Adding 横ばい to the vocabulary
# Adding 公共投資 to the vocabulary
# Adding カ年 to the vocabulary
# Adding maeda to the vocabulary
# Adding jump to the vocabulary
# Adding 愛知県 to the vocabulary
# Adding 有料道路 to the vocabulary
# Adding コンセッション to the vocabulary
# Adding 公共施設 to the vocabulary
# Adding 運営事業 to the vocabulary
# Adding 期首 to the vocabulary
# Adding 手持 to the vocabulary
# Adding 連結子会社 to the vocabulary
# Adding 官公庁 to the vocabulary
# Adding 振替 to the vocabulary
# Adding 引当金 to the vocabulary
# Adding 繰入 to the vocabulary
# Adding 連結損益計算書 to the vocabulary
# Adding 政権交代 to the vocabulary
# Adding 足踏み状態 to the vocabulary
# Adding 再開発 to the vocabulary
# Adding 交通インフラ to the vocabulary
# Adding 需給 to the vocabulary
# Adding 企業価値 to the vocabulary
# Adding 集中的 to the vocabulary
# Adding 強み to the vocabulary
# Adding 事業領域 to the vocabulary
# Adding 経営基盤 to the vocabulary
# Adding 売上総利益 to the vocabulary
# Adding 主因 to the vocabulary
# Adding 消費税 to the vocabulary
# Adding 土木工事 to the vocabulary
# Adding 建築工事 to the vocabulary
# Adding 不動産開発 to the vocabulary
# Adding 引渡し to the vocabulary
# Adding 関係会社 to the vocabulary
# Adding 日本国内 to the vocabulary
# Adding 資機材 to the vocabulary
# Adding 売上総利益率 to the vocabulary
# Adding 地政学的リスク to the vocabulary
# Adding 楽観 to the vocabulary
# Adding 世界情勢 to the vocabulary
# Adding 建設需要 to the vocabulary
# Adding 偏在 to the vocabulary
# Adding 技能労働者 to the vocabulary
# Adding 払拭 to the vocabulary
# Adding 予断 to the vocabulary
# Adding 事業年度 to the vocabulary
# Adding 金融政策 to the vocabulary
# Adding 総動員 to the vocabulary
# Adding 買い控え to the vocabulary
# Adding 粗利率 to the vocabulary
# Adding 第三者割当増資 to the vocabulary
# Adding 仕入 to the vocabulary
# Adding 人手不足 to the vocabulary
# Adding 金属加工 to the vocabulary
# Adding くさび to the vocabulary
# Adding 緊結 to the vocabulary
# Adding 高速道路 to the vocabulary
# Adding 下げ止まり to the vocabulary
# Adding century to the vocabulary
# Adding ヵ年 to the vocabulary
# Adding phase to the vocabulary
# Adding 経営方針 to the vocabulary
# Adding 生産性 to the vocabulary
# Adding 建築設備 to the vocabulary
# Adding 廃棄物処理 to the vocabulary
# Adding 維持管理 to the vocabulary
# Adding 繰越 to the vocabulary
# Adding 原価 to the vocabulary
# Adding 日系企業 to the vocabulary
# Adding vision to the vocabulary
# Adding 総合力 to the vocabulary
# Adding 経常利益率 to the vocabulary
# Adding 過去最高 to the vocabulary
# Adding 変電設備 to the vocabulary
# Adding 電気工事 to the vocabulary
# Adding 情報通信 to the vocabulary
# Adding 携帯電話 to the vocabulary
# Adding 基地局 to the vocabulary
# Adding 東京オリンピック to the vocabulary
# Adding 本格化 to the vocabulary
# Adding 相俟って to the vocabulary
# Adding 成長戦略 to the vocabulary
# Adding アフターサービス to the vocabulary
# Adding 管工事 to the vocabulary
# Adding 事業運営 to the vocabulary
# Adding 高水準 to the vocabulary
# Adding 公共事業 to the vocabulary
# Adding もとで to the vocabulary
# Adding lc to the vocabulary
# Adding 省力 to the vocabulary
# Adding 品質向上 to the vocabulary
# Adding 撲滅 to the vocabulary
# Adding コンプライアンス to the vocabulary
# Adding ict to the vocabulary
# Adding 業務効率化 to the vocabulary
# Adding 被災地 to the vocabulary
# Adding 挽回 to the vocabulary
# Adding 消費者マインド to the vocabulary
# Adding iot to the vocabulary
# Adding 民需 to the vocabulary
# Adding 国土強靭化 to the vocabulary
# Adding 老朽化 to the vocabulary
# Adding インフラ投資 to the vocabulary
# Adding システム化 to the vocabulary
# Adding kaizen to the vocabulary
# Adding 社会インフラ to the vocabulary
# Adding 豪雨災害 to the vocabulary
# Adding 復旧工事 to the vocabulary
# Adding 上期 to the vocabulary
# Adding 株式相場 to the vocabulary
# Adding けん引 to the vocabulary
# Adding ダイダン to the vocabulary
# Adding always to the vocabulary
# Adding 法人税 to the vocabulary
# Adding 住民税 to the vocabulary
# Adding 事業税 to the vocabulary
# Adding 政権移行 to the vocabulary
# Adding 熾烈 to the vocabulary
# Adding 価格競争 to the vocabulary
# Adding コストダウン to the vocabulary
# Adding 発電設備 to the vocabulary
# Adding 営業損益 to the vocabulary
# Adding 空調設備 to the vocabulary
# Adding 電設 to the vocabulary
# Adding 電気設備 to the vocabulary
# Adding 太陽光発電設備 to the vocabulary
# Adding 流通事業 to the vocabulary
# Adding 海外事業 to the vocabulary
# Adding 補正予算 to the vocabulary
# Adding 出来高 to the vocabulary
# Adding マイナス金利政策 to the vocabulary
# Adding 相続税 to the vocabulary
# Adding 節税 to the vocabulary
# Adding 貸家 to the vocabulary
# Adding 資材費 to the vocabulary
# Adding 労務費 to the vocabulary
# Adding 集中豪雨 to the vocabulary
# Adding 公共工事 to the vocabulary
# Adding 優先順位 to the vocabulary
# Adding 工期 to the vocabulary
# Adding 先延ばし to the vocabulary
# Adding 収益性 to the vocabulary
# Adding 気泡 to the vocabulary
# Adding 端境期 to the vocabulary
# Adding 軽量盛土 to the vocabulary
# Adding 一段落 to the vocabulary
# Adding 地盤改良 to the vocabulary
# Adding ずれ込み to the vocabulary
# Adding 固化 to the vocabulary
# Adding 景気対策 to the vocabulary
# Adding 景気回復 to the vocabulary
# Adding 低価格 to the vocabulary
# Adding 物流費 to the vocabulary
# Adding 販売促進 to the vocabulary
# Adding 外食 to the vocabulary
# Adding 歳暮 to the vocabulary
# Adding ギフト to the vocabulary
# Adding 統廃合 to the vocabulary
# Adding 歩留り to the vocabulary
# Adding 遊休 to the vocabulary
# Adding 部門別 to the vocabulary
# Adding 惣菜 to the vocabulary
# Adding ハンバーグ to the vocabulary
# Adding 前年比 to the vocabulary
# Adding 粗糖 to the vocabulary
# Adding 勘案 to the vocabulary
# Adding 状況下 to the vocabulary
# Adding 製販 to the vocabulary
# Adding 先物 to the vocabulary
# Adding 限月 to the vocabulary
# Adding 生産国 to the vocabulary
# Adding 最高値 to the vocabulary
# Adding 歩留 to the vocabulary
# Adding 上白糖 to the vocabulary
# Adding 現物 to the vocabulary
# Adding 期待感 to the vocabulary
# Adding 化粧品 to the vocabulary
# Adding 株式市場 to the vocabulary
# Adding 政府主導 to the vocabulary
# Adding 健康志向 to the vocabulary
# Adding 働き方改革 to the vocabulary
# Adding 社会保障 to the vocabulary
# Adding 品質保証 to the vocabulary
# Adding 顧客満足度 to the vocabulary
# Adding 具体的 to the vocabulary
# Adding 共働き to the vocabulary
# Adding 機敏 to the vocabulary
# Adding フォロー to the vocabulary
# Adding 商品開発 to the vocabulary
# Adding ルマンドアイス to the vocabulary
# Adding アイスクリーム to the vocabulary
# Adding 再生医療 to the vocabulary
# Adding xyltech to the vocabulary
# Adding キシルテック to the vocabulary
# Adding エクセレントスイーツシリーズ to the vocabulary
# Adding 小箱 to the vocabulary
# Adding ビスケット to the vocabulary
# Adding キャンデー to the vocabulary
# Adding 伸張 to the vocabulary
# Adding 米菓 to the vocabulary
# Adding 発酵バター to the vocabulary
# Adding 抹茶 to the vocabulary
# Adding パイン to the vocabulary
# Adding いも to the vocabulary
# Adding マイベネフィット to the vocabulary
# Adding カカオ to the vocabulary
# Adding オリーブオイル to the vocabulary
# Adding ココナッツオイル to the vocabulary
# Adding ショコラ to the vocabulary
# Adding きなこ to the vocabulary
# Adding アルフォートミニチョコレート to the vocabulary
# Adding ブリリアント to the vocabulary
# Adding トリュフ to the vocabulary
# Adding 神戸学院大学 to the vocabulary
# Adding 神戸市 to the vocabulary
# Adding 産学官連携 to the vocabulary
# Adding バニラ to the vocabulary
# Adding チーズおかき to the vocabulary
# Adding フェットチーネ to the vocabulary
# Adding グミ to the vocabulary
# Adding ミックスフルーツソーダ to the vocabulary
# Adding はちみつレモン to the vocabulary
# Adding 新味 to the vocabulary
# Adding フェットチーネグミコーラ to the vocabulary
# Adding ハードボイルド to the vocabulary
# Adding 期間限定 to the vocabulary
# Adding 東京駅一番街 to the vocabulary
# Adding アンテナショップ to the vocabulary
# Adding パティスリーブルボン to the vocabulary
# Adding クッキー to the vocabulary
# Adding 限定商品 to the vocabulary
# Adding ラングレイス to the vocabulary
# Adding ルマンドアソート to the vocabulary
# Adding まろやか to the vocabulary
# Adding ココナッツミルク to the vocabulary
# Adding 販売ルート to the vocabulary
# Adding ココア to the vocabulary
# Adding マルチスタイルスイーツ to the vocabulary
# Adding スライス生チョコレート to the vocabulary
# Adding 訴求 to the vocabulary
# Adding 地震災害 to the vocabulary
# Adding 防災意識 to the vocabulary
# Adding 機能性食品 to the vocabulary
# Adding 機能性表示食品 to the vocabulary
# Adding カラダ to the vocabulary
# Adding みらい to the vocabulary
# Adding 冷菓 to the vocabulary
# Adding 安定化 to the vocabulary
# Adding 新潟県 to the vocabulary
# Adding 富山県 to the vocabulary
# Adding 石川県 to the vocabulary
# Adding 福井県 to the vocabulary
# Adding 甲信 to the vocabulary
# Adding 山梨県 to the vocabulary
# Adding 長野県 to the vocabulary
# Adding 通信販売 to the vocabulary
# Adding 催事 to the vocabulary
# Adding 満足度 to the vocabulary
# Adding リピーター to the vocabulary
# Adding 自動販売機 to the vocabulary
# Adding プチモール to the vocabulary
# Adding 効率性 to the vocabulary
# Adding flying to the vocabulary
# Adding ipa to the vocabulary
# Adding 績 to the vocabulary
# Adding プロバイオティクス to the vocabulary
# Adding 普及活動 to the vocabulary
# Adding 生産設備 to the vocabulary
# Adding 乳製品 to the vocabulary
# Adding 乳酸菌 to the vocabulary
# Adding シロタ株 to the vocabulary
# Adding エビデンス to the vocabulary
# Adding 乳酸菌飲料 to the vocabulary
# Adding lt to the vocabulary
# Adding お客さま to the vocabulary
# Adding 飲用 to the vocabulary
# Adding ヤクルトレディ to the vocabulary
# Adding ヤクルトカロリーハーフ to the vocabulary
# Adding スワローズ to the vocabulary
# Adding 活性化 to the vocabulary
# Adding 地域限定 to the vocabulary
# Adding イトーヨーカドー to the vocabulary
# Adding アイグループ to the vocabulary
# Adding 各店 to the vocabulary
# Adding ヨーグルト to the vocabulary
# Adding ジョア to the vocabulary
# Adding ウォルト・ディズニー・ジャパン株式会社 to the vocabulary
# Adding ピーチ to the vocabulary
# Adding 技術力 to the vocabulary
# Adding 清涼 to the vocabulary
# Adding ミルージュ to the vocabulary
# Adding 栄養ドリンク to the vocabulary
# Adding タフマン to the vocabulary
# Adding 東京ヤクルトスワローズ to the vocabulary
# Adding 機能性飲料 to the vocabulary
# Adding かわきり to the vocabulary
# Adding 米州 to the vocabulary
# Adding 低カロリー to the vocabulary
# Adding 雲南省 to the vocabulary
# Adding 昆明市 to the vocabulary
# Adding 広西チワン族自治区 to the vocabulary
# Adding 南寧市 to the vocabulary
# Adding 太原 to the vocabulary
# Adding ハルビン to the vocabulary
# Adding 嘉興 to the vocabulary
# Adding 販売拠点 to the vocabulary
# Adding はか所 to the vocabulary
# Adding アラブ首長国連邦 to the vocabulary
# Adding uae to the vocabulary
# Adding オマーン to the vocabulary
# Adding バーレーン王国 to the vocabulary
# Adding 海外進出 to the vocabulary
# Adding 販売開始 to the vocabulary
# Adding ヨーロッパ地域 to the vocabulary
# Adding 周辺領域 to the vocabulary
# Adding 抗悪性腫瘍剤 to the vocabulary
# Adding 胃がん to the vocabulary
# Adding 効能 to the vocabulary
# Adding 講演会 to the vocabulary
# Adding 後発医薬品 to the vocabulary
# Adding 上市 to the vocabulary
# Adding 医療機関 to the vocabulary
# Adding 先発医薬品 to the vocabulary
# Adding 情報提供 to the vocabulary
# Adding ゲムシタビンヤクルト to the vocabulary
# Adding 抑制剤 to the vocabulary
# Adding ゾレドロン to the vocabulary
# Adding タキソイド to the vocabulary
# Adding ドセタキセルヤクルト to the vocabulary
# Adding 販路拡大 to the vocabulary
# Adding 薬価 to the vocabulary
# Adding ag to the vocabulary
# Adding hdac to the vocabulary
# Adding 阻害剤 to the vocabulary
# Adding レスミノスタット to the vocabulary
# Adding エテルナゼンタリス to the vocabulary
# Adding pik to the vocabulary
# Adding akt to the vocabulary
# Adding ペリフォシン to the vocabulary
# Adding 日産化学工業株式会社 to the vocabulary
# Adding 共同開発 to the vocabulary
# Adding 血小板 to the vocabulary
# Adding yhi to the vocabulary
# Adding プロ野球 to the vocabulary
# Adding シロタ to the vocabulary
# Adding エッセンス to the vocabulary
# Adding 基礎化粧品 to the vocabulary
# Adding パラビオ to the vocabulary
# Adding リベシィ to the vocabulary
# Adding リベシィホワイト to the vocabulary
# Adding カウンセリング to the vocabulary
# Adding 訪問販売 to the vocabulary
# Adding スキンケア to the vocabulary
# Adding フルリニューアル to the vocabulary
# Adding 神宮球場 to the vocabulary
# Adding 情報発信 to the vocabulary
# Adding ファンサービス to the vocabulary
# Adding 入場者 to the vocabulary
# Adding しょうゆ to the vocabulary
# Adding 食料品 to the vocabulary
# Adding つゆ to the vocabulary
# Adding デルモンテ to the vocabulary
# Adding 調味料 to the vocabulary
# Adding 豆乳 to the vocabulary
# Adding みりん to the vocabulary
# Adding 生し to the vocabulary
# Adding ょうゆのおいしさ to the vocabulary
# Adding やすさ to the vocabulary
# Adding ラインアップ to the vocabulary
# Adding 販促 to the vocabulary
# Adding 白だし to the vocabulary
# Adding 減塩 to the vocabulary
# Adding 本つゆ to the vocabulary
# Adding わが家 to the vocabulary
# Adding 焼肉屋 to the vocabulary
# Adding 旨辛 to the vocabulary
# Adding ごはん to the vocabulary
# Adding リコピンリッチ to the vocabulary
# Adding 広告効果 to the vocabulary
# Adding トマトケチャップ to the vocabulary
# Adding はつゆ to the vocabulary
# Adding 特定保健用食品 to the vocabulary
# Adding 市場拡大 to the vocabulary
# Adding 野菜ジュース to the vocabulary
# Adding トマトジュース to the vocabulary
# Adding 果汁 to the vocabulary
# Adding 本みりん to the vocabulary
# Adding 米麹 to the vocabulary
# Adding 仕込み to the vocabulary
# Adding 料理酒 to the vocabulary
# Adding 国産米 to the vocabulary
# Adding 清酒 to the vocabulary
# Adding 業務用 to the vocabulary
# Adding 国産ワイン to the vocabulary
# Adding 伊勢志摩サミット to the vocabulary
# Adding 日本ワイン to the vocabulary
# Adding 輸入ワイン to the vocabulary
# Adding 減収増益 to the vocabulary
# Adding ヒアルロン酸 to the vocabulary
# Adding 運送事業 to the vocabulary
# Adding グループ会社 to the vocabulary
# Adding 増収減益 to the vocabulary
# Adding 北米市場 to the vocabulary
# Adding ブランド力 to the vocabulary
# Adding 事業展開 to the vocabulary
# Adding きめ細か to the vocabulary
# Adding オセアニア市場 to the vocabulary
# Adding 販売会社 to the vocabulary
# Adding フルーツ缶詰 to the vocabulary
# Adding フィリピン産 to the vocabulary
# Adding パイナップル to the vocabulary
# Adding イギリスのeu離脱 to the vocabulary
# Adding asean to the vocabulary
# Adding ドル高 to the vocabulary
# Adding 関連企業 to the vocabulary
# Adding 即席めん to the vocabulary
# Adding アジア諸国 to the vocabulary
# Adding 資本市場 to the vocabulary
# Adding ブランディング to the vocabulary
# Adding 盤石 to the vocabulary
# Adding 日清食品 to the vocabulary
# Adding カップめん to the vocabulary
# Adding カップヌードル to the vocabulary
# Adding 謎肉 to the vocabulary
# Adding 味付 to the vocabulary
# Adding 豚ミンチ to the vocabulary
# Adding 謎肉祭 to the vocabulary
# Adding ペッパー to the vocabulary
# Adding ロングセラー to the vocabulary
# Adding 日清 to the vocabulary
# Adding どん兵衛 to the vocabulary
# Adding きつねうどん to the vocabulary
# Adding 日清焼そば to the vocabulary
# Adding 明星食品 to the vocabulary
# Adding めん類 to the vocabulary
# Adding チャルメラ to the vocabulary
# Adding 一平ちゃん to the vocabulary
# Adding 夜店 to the vocabulary
# Adding 焼そば to the vocabulary
# Adding チルド to the vocabulary
# Adding ごたえ to the vocabulary
# Adding 冷し中華 to the vocabulary
# Adding 日清食品冷凍 to the vocabulary
# Adding パスタ to the vocabulary
# Adding 挽肉 to the vocabulary
# Adding まいたけ to the vocabulary
# Adding クリーミーボロネーゼ to the vocabulary
# Adding 食感 to the vocabulary
# Adding 生パスタ to the vocabulary
# Adding 辣椒 to the vocabulary
# Adding 担々麺 to the vocabulary
# Adding 日清具多 to the vocabulary
# Adding 清中 to the vocabulary
# Adding 汁なし担々麺 to the vocabulary
# Adding 大盛り to the vocabulary
# Adding 汁なし麺 to the vocabulary
# Adding 具材 to the vocabulary
# Adding 鴨南蛮 to the vocabulary
# Adding cup to the vocabulary
# Adding noodles to the vocabulary
# Adding ニッシンフーズブラジル to the vocabulary
# Adding ltda to the vocabulary
# Adding ニッシン to the vocabulary
# Adding アジノモト to the vocabulary
# Adding メントス to the vocabulary
# Adding 中国大陸 to the vocabulary
# Adding 味道 to the vocabulary
# Adding 華南 to the vocabulary
# Adding 出前一丁 to the vocabulary
# Adding 香港国際空港 to the vocabulary
# Adding マイカップヌードルファクトリー to the vocabulary
# Adding ファクトリー to the vocabulary
# Adding アジア地域 to the vocabulary
# Adding 個人所得 to the vocabulary
# Adding 資源価格 to the vocabulary
# Adding 値動き to the vocabulary
# Adding 下振れリスク to the vocabulary
# Adding 年明け to the vocabulary
# Adding 合理化 to the vocabulary
# Adding 即席麺 to the vocabulary
# Adding 全社 to the vocabulary
# Adding 粉粒体 to the vocabulary
# Adding 顆粒 to the vocabulary
# Adding 生ラーメン to the vocabulary
# Adding 経済財政政策 to the vocabulary
# Adding 内需 to the vocabulary
# Adding 構造改革 to the vocabulary
# Adding 焼肉のたれ to the vocabulary
# Adding 生鮮 to the vocabulary
# Adding 新製品開発 to the vocabulary
# Adding 手羽 to the vocabulary
# Adding 赤身肉 to the vocabulary
# Adding 熟成肉 to the vocabulary
# Adding 甘口 to the vocabulary
# Adding 黒酢 to the vocabulary
# Adding あんかけ to the vocabulary
# Adding 多様化 to the vocabulary
# Adding 新製品 to the vocabulary
# Adding 秋冬 to the vocabulary
# Adding ちゃんこ鍋 to the vocabulary
# Adding 不作 to the vocabulary
# Adding もやし to the vocabulary
# Adding もつ鍋 to the vocabulary
# Adding 全国展開 to the vocabulary
# Adding 塩こしょう to the vocabulary
# Adding 奏功 to the vocabulary
# Adding 精肉 to the vocabulary
# Adding スープはるさめ to the vocabulary
# Adding 円安進行 to the vocabulary
# Adding 外需 to the vocabulary
# Adding 企業活動 to the vocabulary
# Adding 一進一退 to the vocabulary
# Adding 大型商業施設 to the vocabulary
# Adding 集客力 to the vocabulary
# Adding 営業収益 to the vocabulary
# Adding 事業別 to the vocabulary
# Adding マテリアル to the vocabulary
# Adding レーヨン to the vocabulary
# Adding ポリエステル to the vocabulary
# Adding アパレル to the vocabulary
# Adding 堅実 to the vocabulary
# Adding 追い風 to the vocabulary
# Adding カジュアル to the vocabulary
# Adding ユミカツラ to the vocabulary
# Adding ミュゼ to the vocabulary
# Adding ジョワイユ to the vocabulary
# Adding ディレツィオーネ to the vocabulary
# Adding メンズ to the vocabulary
# Adding 販売員 to the vocabulary
# Adding フロリア to the vocabulary
# Adding ノベルティ to the vocabulary
# Adding 服地 to the vocabulary
# Adding イオンモール川口前川 to the vocabulary
# Adding 近隣住民 to the vocabulary
# Adding 生活環境 to the vocabulary
# Adding 専門店 to the vocabulary
# Adding イオンモール川口 to the vocabulary
# Adding 契約期間 to the vocabulary
# Adding 契約更新 to the vocabulary
# Adding 減額 to the vocabulary
# Adding ゴルフ練習場 to the vocabulary
# Adding 黒浜 to the vocabulary
# Adding 騎西 to the vocabulary
# Adding 練習場 to the vocabulary
# Adding 人工芝 to the vocabulary
# Adding 若年層 to the vocabulary
# Adding 事業部 to the vocabulary
# Adding 葬祭 to the vocabulary
# Adding 返礼 to the vocabulary
# Adding 緑化 to the vocabulary
# Adding 観葉 to the vocabulary
# Adding 慶弔用 to the vocabulary
# Adding 花卉 to the vocabulary
# Adding サイボー to the vocabulary
# Adding 入替え to the vocabulary
# Adding 年初 to the vocabulary
# Adding 利上げ to the vocabulary
# Adding 乱高下 to the vocabulary
# Adding 最安値 to the vocabulary
# Adding トランプ政権 to the vocabulary
# Adding 日経平均株価 to the vocabulary
# Adding 年初来高値 to the vocabulary
# Adding 大納会 to the vocabulary
# Adding 投資銀行 to the vocabulary
# Adding 上場企業 to the vocabulary
# Adding 事業再生 to the vocabulary
# Adding 事業戦略 to the vocabulary
# Adding エクイティファイナンス to the vocabulary
# Adding 引受け to the vocabulary
# Adding 金融庁 to the vocabulary
# Adding 証券取引 to the vocabulary
# Adding 厳正 to the vocabulary
# Adding 透明性 to the vocabulary
# Adding 資金調達 to the vocabulary
# Adding 担い手 to the vocabulary
# Adding ir to the vocabulary
# Adding 一定の成果 to the vocabulary
# Adding 多角化 to the vocabulary
# Adding 経営戦略 to the vocabulary
# Adding 事業会社 to the vocabulary
# Adding 海外投資 to the vocabulary
# Adding 政治経済 to the vocabulary
# Adding 注視 to the vocabulary
# Adding 株主価値 to the vocabulary
# Adding キャピタルゲイン to the vocabulary
# Adding 個別財務諸表 to the vocabulary
# Adding 引受 to the vocabulary
# Adding 訪日外国人 to the vocabulary
# Adding 寝具 to the vocabulary
# Adding bridge to the vocabulary
# Adding future to the vocabulary
# Adding 未来へ to the vocabulary
# Adding 架け橋 to the vocabulary
# Adding プロパー to the vocabulary
# Adding 底上げ to the vocabulary
# Adding 最優先 to the vocabulary
# Adding 借入金 to the vocabulary
# Adding シンジケートローン to the vocabulary
# Adding 商業施設 to the vocabulary
# Adding 静岡県下 to the vocabulary
# Adding サントムーン柿田川 to the vocabulary
# Adding 適宜 to the vocabulary
# Adding ヘルスケア to the vocabulary
# Adding eコマース to the vocabulary
# Adding ウール to the vocabulary
# Adding 温熱 to the vocabulary
# Adding 電位治療器 to the vocabulary
# Adding 営業力 to the vocabulary
# Adding アライアンス to the vocabulary
# Adding 業務提携 to the vocabulary
# Adding 販売管理費 to the vocabulary
# Adding 負担増 to the vocabulary
# Adding 中途解約 to the vocabulary
# Adding 縫製 to the vocabulary
# Adding 持分 to the vocabulary
# Adding 加味 to the vocabulary
# Adding ヒット作 to the vocabulary
# Adding 減価償却費 to the vocabulary
# Adding 毛布 to the vocabulary
# Adding 寝装品 to the vocabulary
# Adding 原材料費 to the vocabulary
# Adding 暖冬 to the vocabulary
# Adding 落ち込み to the vocabulary
# Adding 黒字転換 to the vocabulary
# Adding 会計処理 to the vocabulary
# Adding 税抜 to the vocabulary
# Adding 減少傾向 to the vocabulary
# Adding 売上拡大 to the vocabulary
# Adding 販社 to the vocabulary
# Adding 販路開拓 to the vocabulary
# Adding 生産拠点 to the vocabulary
# Adding 積極的 to the vocabulary
# Adding 企業内保育所 to the vocabulary
# Adding テキスタイル to the vocabulary
# Adding 無地 to the vocabulary
# Adding 販売不振 to the vocabulary
# Adding 販売拡大 to the vocabulary
# Adding 円安基調 to the vocabulary
# Adding 下期 to the vocabulary
# Adding 全面的 to the vocabulary
# Adding 託児所 to the vocabulary
# Adding 業容 to the vocabulary
# Adding 保育士 to the vocabulary
# Adding 採用活動 to the vocabulary
# Adding 商量 to the vocabulary
# Adding 浮揚 to the vocabulary
# Adding 懸案 to the vocabulary
# Adding デフレ脱却 to the vocabulary
# Adding 緊迫 to the vocabulary
# Adding 足許 to the vocabulary
# Adding 消費市場 to the vocabulary
# Adding 退潮 to the vocabulary
# Adding 市場参入 to the vocabulary
# Adding オーバーストア to the vocabulary
# Adding 昂進 to the vocabulary
# Adding 市場構造 to the vocabulary
# Adding 持分法適用会社 to the vocabulary
# Adding アウトドア to the vocabulary
# Adding ザ・ノース・フェイス to the vocabulary
# Adding ヘリー・ハンセン to the vocabulary
# Adding 春夏 to the vocabulary
# Adding 直営店 to the vocabulary
# Adding アスレチック to the vocabulary
# Adding カンタベリー・オブ・ニュージーランド to the vocabulary
# Adding ブラックアンドホワイト to the vocabulary
# Adding エレッセ to the vocabulary
# Adding ナショナルスポーツ to the vocabulary
# Adding ウエア to the vocabulary
# Adding 在庫過多 to the vocabulary
# Adding 事業譲渡 to the vocabulary
# Adding 粗利益 to the vocabulary
# Adding リテール to the vocabulary
# Adding 大幅増 to the vocabulary
# Adding 賃借 to the vocabulary
# Adding 持分法適用関連会社 to the vocabulary
# Adding youngone to the vocabulary
# Adding outdoor to the vocabulary
# Adding corporation to the vocabulary
# Adding 持分法投資利益 to the vocabulary
# Adding 不採算 to the vocabulary
# Adding 減損 to the vocabulary
# Adding 差引 to the vocabulary
# Adding 過去最高益 to the vocabulary
# Adding 株安 to the vocabulary
# Adding 景況感 to the vocabulary
# Adding 上向き to the vocabulary
# Adding 中国経済 to the vocabulary
# Adding 中東情勢 to the vocabulary
# Adding 復調 to the vocabulary
# Adding 軌を一にする to the vocabulary
# Adding 生産活動 to the vocabulary
# Adding 製造業 to the vocabulary
# Adding 非製造業 to the vocabulary
# Adding 完全雇用 to the vocabulary
# Adding 可処分所得 to the vocabulary
# Adding 物価上昇 to the vocabulary
# Adding 日本企業 to the vocabulary
# Adding 米麦 to the vocabulary
# Adding 昭和パックス to the vocabulary
# Adding 会計期間 to the vocabulary
# Adding クラフト紙袋 to the vocabulary
# Adding 為替レート to the vocabulary
# Adding 紙工 to the vocabulary
# Adding 小口 to the vocabulary
# Adding ネスコ to the vocabulary
# Adding ㈲ to the vocabulary
# Adding 米袋 to the vocabulary
# Adding 連係 to the vocabulary
# Adding 減価償却 to the vocabulary
# Adding ゴミ袋 to the vocabulary
# Adding 全国的 to the vocabulary
# Adding 集荷 to the vocabulary
# Adding 製粉 to the vocabulary
# Adding 澱粉 to the vocabulary
# Adding 合成樹脂 to the vocabulary
# Adding ポリエチレン to the vocabulary
# Adding 増産 to the vocabulary
# Adding 陣容 to the vocabulary
# Adding 取込 to the vocabulary
# Adding 低密度ポリエチレン to the vocabulary
# Adding hqf to the vocabulary
# Adding アスベスト to the vocabulary
# Adding バーナルハウス to the vocabulary
# Adding ポリスチレン to the vocabulary
# Adding 原油価格 to the vocabulary
# Adding 値上がり to the vocabulary
# Adding コンテナー to the vocabulary
# Adding 粒状 to the vocabulary
# Adding 内容物 to the vocabulary
# Adding ワンウェイ to the vocabulary
# Adding フレコン to the vocabulary
# Adding 出荷量 to the vocabulary
# Adding 除染 to the vocabulary
# Adding インナー to the vocabulary
# Adding バルコン to the vocabulary
# Adding 絶対数 to the vocabulary
# Adding ℓ to the vocabulary
# Adding エスキューブ to the vocabulary
# Adding エスタンク to the vocabulary
# Adding ありません to the vocabulary
# Adding 金融緩和政策 to the vocabulary
# Adding 印刷物 to the vocabulary
# Adding 紙媒体 to the vocabulary
# Adding 競争激化 to the vocabulary
# Adding dnp to the vocabulary
# Adding モビリティ to the vocabulary
# Adding printing to the vocabulary
# Adding information to the vocabulary
# Adding 利便性 to the vocabulary
# Adding 本人確認 to the vocabulary
# Adding サイバートラスト株式会社 to the vocabulary
# Adding 協業 to the vocabulary
# Adding ポータルサイト to the vocabulary
# Adding 地域通貨 to the vocabulary
# Adding 株式会社フューチャーリンクネットワーク to the vocabulary
# Adding sig to the vocabulary
# Adding エスアイジー to the vocabulary
# Adding コンビブロックグループ to the vocabulary
# Adding 日本市場 to the vocabulary
# Adding ブラインド to the vocabulary
# Adding シェード to the vocabulary
# Adding 耐候性 to the vocabulary
# Adding 耐摩耗性 to the vocabulary
# Adding 地球環境 to the vocabulary
# Adding 効果的 to the vocabulary
# Adding 採光 to the vocabulary
# Adding 消費電力 to the vocabulary
# Adding 環境保全 to the vocabulary
# Adding 地球環境大賞 to the vocabulary
# Adding 日本経済団体連合会 to the vocabulary
# Adding 書店員 to the vocabulary
# Adding ネット通販 to the vocabulary
# Adding 電子書籍 to the vocabulary
# Adding honto to the vocabulary
# Adding 事業拡大 to the vocabulary
# Adding チラシ to the vocabulary
# Adding pop to the vocabulary
# Adding 金融機関 to the vocabulary
# Adding 電子マネー to the vocabulary
# Adding icカード to the vocabulary
# Adding データ入力 to the vocabulary
# Adding ips to the vocabulary
# Adding processing to the vocabulary
# Adding services to the vocabulary
# Adding 情報セキュリティ to the vocabulary
# Adding 生活者視点 to the vocabulary
# Adding マーケティングコミュニケーション to the vocabulary
# Adding コミュニケーションデザイン to the vocabulary
# Adding ワンストップ to the vocabulary
# Adding イメージング to the vocabulary
# Adding 記念撮影 to the vocabulary
# Adding フォトブース to the vocabulary
# Adding goo to the vocabulary
# Adding シャグー to the vocabulary
# Adding 写真機 to the vocabulary
# Adding ki to the vocabulary
# Adding キレイ to the vocabulary
# Adding 昇華 to the vocabulary
# Adding 熱転写 to the vocabulary
# Adding カラーインク to the vocabulary
# Adding 受像 to the vocabulary
# Adding 紙カップ to the vocabulary
# Adding 成型 to the vocabulary
# Adding ペットボトル to the vocabulary
# Adding 無菌 to the vocabulary
# Adding 生活空間 to the vocabulary
# Adding eb to the vocabulary
# Adding electron to the vocabulary
# Adding beam to the vocabulary
# Adding コーティング to the vocabulary
# Adding 太陽電池 to the vocabulary
# Adding 海外向け to the vocabulary
# Adding 車載 to the vocabulary
# Adding 有機elディスプレイ to the vocabulary
# Adding 液晶ディスプレイ to the vocabulary
# Adding カラーフィルター to the vocabulary
# Adding タブレット端末 to the vocabulary
# Adding 偏光板 to the vocabulary
# Adding フォトマスク to the vocabulary
# Adding ナショナルブランド to the vocabulary
# Adding プライベートブランド to the vocabulary
# Adding エリアマーケティング to the vocabulary
# Adding 量販店 to the vocabulary
# Adding ミネラルウォーター to the vocabulary
# Adding い・ろ・は・す to the vocabulary
# Adding 綾鷹 to the vocabulary
# Adding 茶飲 to the vocabulary
# Adding グループボトラー to the vocabulary
# Adding コカ・コーラ to the vocabulary
# Adding 電子出版 to the vocabulary
# Adding 歯止め to the vocabulary
# Adding 広告宣伝費 to the vocabulary
# Adding インターネット広告 to the vocabulary
# Adding 人財 to the vocabulary
# Adding モバイル端末 to the vocabulary
# Adding 有効活用 to the vocabulary
# Adding 学習参考書 to the vocabulary
# Adding 児童書 to the vocabulary
# Adding 重点的 to the vocabulary
# Adding bpo to the vocabulary
# Adding qms to the vocabulary
# Adding 品質マネジメントシステム to the vocabulary
# Adding 一人ひとり to the vocabulary
# Adding 販売費及び一般管理費 to the vocabulary
# Adding リーフレット to the vocabulary
# Adding 教師用指導書 to the vocabulary
# Adding 米国大統領 to the vocabulary
# Adding 訪日外国人観光客 to the vocabulary
# Adding インバウンド to the vocabulary
# Adding digjapan to the vocabulary
# Adding クーポン to the vocabulary
# Adding 微博 to the vocabulary
# Adding ウェイボー to the vocabulary
# Adding 微信 to the vocabulary
# Adding 台湾企業 to the vocabulary
# Adding digtaiwan to the vocabulary
# Adding 配信サービス to the vocabulary
# Adding mapple to the vocabulary
# Adding api to the vocabulary
# Adding 多言語 to the vocabulary
# Adding wechatpay to the vocabulary
# Adding ソリューションシステム to the vocabulary
# Adding qfpay to the vocabulary
# Adding ウィズ・パートナーズ to the vocabulary
# Adding japan to the vocabulary
# Adding 海外旅行 to the vocabulary
# Adding 予約サービス to the vocabulary
# Adding グルヤク to the vocabulary
# Adding 譲受 to the vocabulary
# Adding 相乗効果 to the vocabulary
# Adding まっぷるマガジン to the vocabulary
# Adding まっぷる to the vocabulary
# Adding トリプコン to the vocabulary
# Adding おでかけ to the vocabulary
# Adding 比較サイト to the vocabulary
# Adding tripcon to the vocabulary
# Adding 一元管理 to the vocabulary
# Adding 宿泊施設 to the vocabulary
# Adding トリプコンビズ to the vocabulary
# Adding 発売開始 to the vocabulary
# Adding りっぷ to the vocabulary
# Adding 文房具 to the vocabulary
# Adding カーナビゲーション to the vocabulary
# Adding アプリケーションソフト to the vocabulary
# Adding マップルナビ to the vocabulary
# Adding ナビアプリ to the vocabulary
# Adding 継続的 to the vocabulary
# Adding 小さな旅 to the vocabulary
# Adding mini to the vocabulary
# Adding 改訂版 to the vocabulary
# Adding 旧版 to the vocabulary
# Adding 入替 to the vocabulary
# Adding 返品 to the vocabulary
# Adding 差額 to the vocabulary
# Adding 戻入 to the vocabulary
# Adding 賞与 to the vocabulary
# Adding 貸倒引当金 to the vocabulary
# Adding 製造原価 to the vocabulary
# Adding 根本的 to the vocabulary
# Adding 前倒し to the vocabulary
# Adding 損失額 to the vocabulary
# Adding 損失計上 to the vocabulary
# Adding 会計基準 to the vocabulary
# Adding 可能性 to the vocabulary
# Adding 工具器具備品 to the vocabulary
# Adding 化学工業 to the vocabulary
# Adding フッ素 to the vocabulary
# Adding ソーダ to the vocabulary
# Adding 塩酸 to the vocabulary
# Adding トリクロールエチレン to the vocabulary
# Adding パークロールエチレン to the vocabulary
# Adding 三フッ化窒素 to the vocabulary
# Adding タングステン to the vocabulary
# Adding リン酸 to the vocabulary
# Adding 複写機 to the vocabulary
# Adding キャリヤー to the vocabulary
# Adding 酸化物 to the vocabulary
# Adding 量的 to the vocabulary
# Adding 重要性 to the vocabulary
# Adding アセチレン to the vocabulary
# Adding 電炉 to the vocabulary
# Adding アルゴン to the vocabulary
# Adding 液化石油ガス to the vocabulary
# Adding 冬場 to the vocabulary
# Adding 器材 to the vocabulary
# Adding 製氷 to the vocabulary
# Adding 不安要素 to the vocabulary
# Adding 基本方針 to the vocabulary
# Adding 適正化 to the vocabulary
# Adding 業績改善 to the vocabulary
# Adding 中間体 to the vocabulary
# Adding 接着剤 to the vocabulary
# Adding ワニス to the vocabulary
# Adding 可塑剤 to the vocabulary
# Adding 化学分析 to the vocabulary
# Adding 作業環境測定 to the vocabulary
# Adding 自動車産業 to the vocabulary
# Adding 販売台数 to the vocabulary
# Adding 普通自動車 to the vocabulary
# Adding ガソリン価格 to the vocabulary
# Adding 自動車販売 to the vocabulary
# Adding 住宅ローン to the vocabulary
# Adding 薄型テレビ to the vocabulary
# Adding クラック to the vocabulary
# Adding 海外市場 to the vocabulary
# Adding リフォーム to the vocabulary
# Adding ペースト to the vocabulary
# Adding ドータイト to the vocabulary
# Adding トナー to the vocabulary
# Adding レジン to the vocabulary
# Adding アクリ to the vocabulary
# Adding メディカル to the vocabulary
# Adding 粘着剤 to the vocabulary
# Adding 藤光樹脂株式会社 to the vocabulary
# Adding アクリル樹脂 to the vocabulary
# Adding 液晶テレビ to the vocabulary
# Adding 技術革新 to the vocabulary
# Adding 産業別 to the vocabulary
# Adding 自動車業界 to the vocabulary
# Adding 建材 to the vocabulary
# Adding 消費税率 to the vocabulary
# Adding 住宅着工件数 to the vocabulary
# Adding 買い替え to the vocabulary
# Adding グローバルな to the vocabulary
# Adding 海外需要 to the vocabulary
# Adding ベトナム国 to the vocabulary
# Adding コンパウンド to the vocabulary
# Adding ビコンパウンド to the vocabulary
# Adding エラストマーコンパウンド to the vocabulary
# Adding タイ国 to the vocabulary
# Adding 取込み to the vocabulary
# Adding フイルム to the vocabulary
# Adding パワービルダー to the vocabulary
# Adding 家電メーカー to the vocabulary
# Adding 新規採用 to the vocabulary
# Adding 塩ビ to the vocabulary
# Adding 小巻 to the vocabulary
# Adding 同業他社 to the vocabulary
# Adding 事業撤退 to the vocabulary
# Adding 低採算 to the vocabulary
# Adding 代理店 to the vocabulary
# Adding 大統領選挙 to the vocabulary
# Adding ナフサ to the vocabulary
# Adding クラッカー to the vocabulary
# Adding パッケージング to the vocabulary
# Adding ポリプロピレン to the vocabulary
# Adding エラストマー to the vocabulary
# Adding 軽量化 to the vocabulary
# Adding 供給力 to the vocabulary
# Adding 生産能力 to the vocabulary
# Adding 不織布 to the vocabulary
# Adding 紙おむつ to the vocabulary
# Adding pi to the vocabulary
# Adding solinnos to the vocabulary
# Adding cuulong to the vocabulary
# Adding belchim to the vocabulary
# Adding 資本提携 to the vocabulary
# Adding 国内需要 to the vocabulary
# Adding 世界初 to the vocabulary
# Adding ポリウレタン to the vocabulary
# Adding フォルティモ to the vocabulary
# Adding スタビオ to the vocabulary
# Adding 石化 to the vocabulary
# Adding 新会社 to the vocabulary
# Adding ポリマー to the vocabulary
# Adding 固定費 to the vocabulary
# Adding 用材 to the vocabulary
# Adding フェノール to the vocabulary
# Adding テレフタル酸 to the vocabulary
# Adding アドバンストマテリアルズ to the vocabulary
# Adding 正極 to the vocabulary
# Adding 発泡プラスチック to the vocabulary
# Adding 掘り起こし to the vocabulary
# Adding 押出 to the vocabulary
# Adding 発泡ポリエチレン to the vocabulary
# Adding ミラマット to the vocabulary
# Adding 気泡緩衝材 to the vocabulary
# Adding キャプロン to the vocabulary
# Adding 発泡 to the vocabulary
# Adding スチレンペーパー to the vocabulary
# Adding 電子レンジ to the vocabulary
# Adding 折箱 to the vocabulary
# Adding ポリスチレンボード to the vocabulary
# Adding ミラボード to the vocabulary
# Adding ミラフォーム to the vocabulary
# Adding 割付 to the vocabulary
# Adding 断裁 to the vocabulary
# Adding ビーズ to the vocabulary
# Adding 世界各国 to the vocabulary
# Adding ピーブロック to the vocabulary
# Adding 家電製品 to the vocabulary
# Adding 緩衝材 to the vocabulary
# Adding 緩衝 to the vocabulary
# Adding スチロダイア to the vocabulary
# Adding ユニットバス to the vocabulary
# Adding 梱包材 to the vocabulary
# Adding 警戒感 to the vocabulary
# Adding polypore to the vocabulary
# Adding ケミカル to the vocabulary
# Adding キュプラ to the vocabulary
# Adding ベンベルグ to the vocabulary
# Adding 皮革 to the vocabulary
# Adding ラムース to the vocabulary
# Adding ナイロン to the vocabulary
# Adding レオナ to the vocabulary
# Adding 石油化学 to the vocabulary
# Adding スチレンモノマー to the vocabulary
# Adding アクリロニトリル to the vocabulary
# Adding マテリアルズ to the vocabulary
# Adding 消費財 to the vocabulary
# Adding イオン交換膜 to the vocabulary
# Adding サランラップ to the vocabulary
# Adding ™ to the vocabulary
# Adding セパレータ to the vocabulary
# Adding デュッセルドルフ市 to the vocabulary
# Adding 旭化成 to the vocabulary
# Adding 宮崎県延岡市 to the vocabulary
# Adding ベンリーゼ to the vocabulary
# Adding 滋賀県守山市 to the vocabulary
# Adding リチウムイオン二次電池 to the vocabulary
# Adding ポア to the vocabulary
# Adding 戸建 to the vocabulary
# Adding へーベルハウス to the vocabulary
# Adding 集合住宅 to the vocabulary
# Adding ヘーベルメゾン to the vocabulary
# Adding 引渡 to the vocabulary
# Adding 断熱材 to the vocabulary
# Adding ネオマ to the vocabulary
# Adding alc to the vocabulary
# Adding 中高層 to the vocabulary
# Adding ヘーベルビルズ to the vocabulary
# Adding 茨城県猿島 to the vocabulary
# Adding ラボラトリー to the vocabulary
# Adding 骨粗鬆症 to the vocabulary
# Adding テリボン to the vocabulary
# Adding リコモジュリン to the vocabulary
# Adding 排尿障害 to the vocabulary
# Adding フリバス to the vocabulary
# Adding プラノバ to the vocabulary
# Adding 透析 to the vocabulary
# Adding 償還 to the vocabulary
# Adding クリティカル to the vocabulary
# Adding 除細動器 to the vocabulary
# Adding lifevest to the vocabulary
# Adding 財務諸表 to the vocabulary
# Adding 年回 to the vocabulary
# Adding 点滴 to the vocabulary
# Adding リクラスト to the vocabulary
# Adding 大分県大分市 to the vocabulary
# Adding bioex to the vocabulary
# Adding 紡糸 to the vocabulary
# Adding 剥落 to the vocabulary
# Adding 財政支出 to the vocabulary
# Adding 売価 to the vocabulary
# Adding 有限公司 to the vocabulary
# Adding 値下がり to the vocabulary
# Adding 厚生年金 to the vocabulary
# Adding 基金解散 to the vocabulary
# Adding 少額 to the vocabulary
# Adding 界面活性剤 to the vocabulary
# Adding トイレタリー to the vocabulary
# Adding ヘアケア to the vocabulary
# Adding 洗浄剤 to the vocabulary
# Adding 帯電防止剤 to the vocabulary
# Adding 乳化重合 to the vocabulary
# Adding 消泡剤 to the vocabulary
# Adding ガラス繊維 to the vocabulary
# Adding エマルション to the vocabulary
# Adding フロアー to the vocabulary
# Adding ポリッシュ to the vocabulary
# Adding 全般的 to the vocabulary
# Adding abs樹脂 to the vocabulary
# Adding ロジン to the vocabulary
# Adding 油剤 to the vocabulary
# Adding 切削 to the vocabulary
# Adding スペシャリティーケミカル to the vocabulary
# Adding 溶剤 to the vocabulary
# Adding 情報産業 to the vocabulary
# Adding アクリレート to the vocabulary
# Adding 日用 to the vocabulary
# Adding 塗装工事 to the vocabulary
# Adding diy to the vocabulary
# Adding カベ to the vocabulary
# Adding 障子紙 to the vocabulary
# Adding ワックス to the vocabulary
# Adding サービス業 to the vocabulary
# Adding 環境負荷 to the vocabulary
# Adding 水性 to the vocabulary
# Adding 展示会 to the vocabulary
# Adding 障がい者 to the vocabulary
# Adding 阿童 to the vocabulary
# Adding 無錫 to the vocabulary
# Adding インターネット通販 to the vocabulary
# Adding 販売チャネル to the vocabulary
# Adding 仕掛 to the vocabulary
# Adding 抗がん剤 to the vocabulary
# Adding レンビマ to the vocabulary
# Adding kisplyx to the vocabulary
# Adding てんかん to the vocabulary
# Adding フィコンパ to the vocabulary
# Adding fycompa to the vocabulary
# Adding eaファーマ株式会社 to the vocabulary
# Adding ハラヴェン to the vocabulary
# Adding 肥満症 to the vocabulary
# Adding belviq to the vocabulary
# Adding ea to the vocabulary
# Adding ファーマ to the vocabulary
# Adding 割安 to the vocabulary
# Adding マイルストンペイメント to the vocabulary
# Adding 当期利益 to the vocabulary
# Adding 所有者 to the vocabulary
# Adding 基本的 to the vocabulary
# Adding 包括利益 to the vocabulary
# Adding 加減 to the vocabulary
# Adding 医療用 to the vocabulary
# Adding ジェネリック医薬品 to the vocabulary
# Adding 一般用医薬品 to the vocabulary
# Adding アメリカス to the vocabulary
# Adding アセアン to the vocabulary
# Adding emea to the vocabulary
# Adding 粧 to the vocabulary
# Adding 算定 to the vocabulary
# Adding 管理費 to the vocabulary
# Adding エーディア to the vocabulary
# Adding 別売 to the vocabulary
# Adding ニューロロジー to the vocabulary
# Adding 不眠症 to the vocabulary
# Adding ルネスタ to the vocabulary
# Adding ファイザー to the vocabulary
# Adding 疼痛 to the vocabulary
# Adding リリカ to the vocabulary
# Adding アルツハイマー to the vocabulary
# Adding レビー小体型認知症 to the vocabulary
# Adding アリセプト to the vocabulary
# Adding オンコロジー to the vocabulary
# Adding tnf to the vocabulary
# Adding モノクローナル抗体 to the vocabulary
# Adding ヒュミラ to the vocabulary
# Adding 新発売 to the vocabulary
# Adding チョコラbb to the vocabulary
# Adding 口内 to the vocabulary
# Adding リペアショット to the vocabulary
# Adding リッチセラミド to the vocabulary
# Adding banzel to the vocabulary
# Adding 吐剤 to the vocabulary
# Adding aloxi to the vocabulary
# Adding lorcaserin to the vocabulary
# Adding 日回 to the vocabulary
# Adding xr to the vocabulary
# Adding 神経障害 to the vocabulary
# Adding メチコバール to the vocabulary
# Adding 強力ネオミノファーゲンシー to the vocabulary
# Adding グリチロン to the vocabulary
# Adding プロトンポンプ to the vocabulary
# Adding パリエット to the vocabulary
# Adding zonegran to the vocabulary
# Adding zebinix to the vocabulary
# Adding サンノーバ株式会社 to the vocabulary
# Adding 剰余金 to the vocabulary
# Adding 負債比率 to the vocabulary
# Adding ネットキャッシュ to the vocabulary
# Adding 有利子負債 to the vocabulary
# Adding 社債 to the vocabulary
# Adding 現金同等物 to the vocabulary
# Adding 先進国 to the vocabulary
# Adding 後発品 to the vocabulary
# Adding 医療費 to the vocabulary
# Adding 新薬 to the vocabulary
# Adding 収載 to the vocabulary
# Adding 引下げ to the vocabulary
# Adding 情報サービス to the vocabulary
# Adding 足取り to the vocabulary
# Adding 高リン血症 to the vocabulary
# Adding 治療薬 to the vocabulary
# Adding ピートルチュアブル to the vocabulary
# Adding 前立腺肥大症 to the vocabulary
# Adding ユリーフ to the vocabulary
# Adding od to the vocabulary
# Adding 糖尿病 to the vocabulary
# Adding グルベス to the vocabulary
# Adding グルファスト to the vocabulary
# Adding 国内販売 to the vocabulary
# Adding シロドシン to the vocabulary
# Adding 日本製品 to the vocabulary
# Adding 導出 to the vocabulary
# Adding アラガン to the vocabulary
# Adding レコルダッチ to the vocabulary
# Adding アスペン to the vocabulary
# Adding 免疫抑制剤 to the vocabulary
# ...
# Adding グローバル市場 to the vocabulary
# Adding ディストリビューター to the vocabulary
# Adding アメリカ大統領選挙 to the vocabulary
# Adding 外国人観光客 to the vocabulary
# Adding 史上最多 to the vocabulary
# Adding 経営理念 to the vocabulary
# Adding ブランドスローガン to the vocabulary
# Adding 来園 to the vocabulary
# Adding 満足感 to the vocabulary
# Adding リスクマネジメント to the vocabulary
# Adding 伊豆シャボテン動物公園 to the vocabulary
# Adding カピバラ to the vocabulary
# Adding 露天風呂 to the vocabulary
# Adding 冬至 to the vocabulary
# Adding ゆず湯 to the vocabulary
# Adding 心待ち to the vocabulary
# Adding オグロマーモセット to the vocabulary
# Adding ショウガラゴ to the vocabulary
# Adding 仲間入り to the vocabulary
# Adding インドクジャク to the vocabulary
# Adding マーラ to the vocabulary
# Adding 伊豆ぐらんぱる公園 to the vocabulary
# Adding led to the vocabulary
# Adding イルミネーション to the vocabulary
# Adding グランイルミ to the vocabulary
# Adding 体験型 to the vocabulary
# Adding 球数 to the vocabulary
# Adding 倍増 to the vocabulary
# Adding ジップライン to the vocabulary
# Adding julie to the vocabulary
# Adding 宝探し to the vocabulary
# Adding gold to the vocabulary
# Adding rush to the vocabulary
# Adding ソテッチー to the vocabulary
# Adding 秘宝 to the vocabulary
# Adding 縦横無尽 to the vocabulary
# Adding トルネード to the vocabulary
# Adding vr to the vocabulary
# Adding バーチャルライド to the vocabulary
# Adding magica to the vocabulary
# Adding 二次使用 to the vocabulary
# Adding 制御装置 to the vocabulary
# Adding ハーネス to the vocabulary
# Adding 新分野 to the vocabulary
# Adding 遊技 to the vocabulary
# Adding ソケット to the vocabulary
# Adding フローティングコネクタ to the vocabulary
# Adding 監視カメラ to the vocabulary
# Adding 極細 to the vocabulary
# Adding 同軸ケーブル to the vocabulary
# Adding 通信機器 to the vocabulary
# Adding 特注 to the vocabulary
# Adding 電力機器 to the vocabulary
# Adding ct to the vocabulary
# Adding mri to the vocabulary
# Adding 安全運転 to the vocabulary
# Adding adas to the vocabulary
# Adding 先進運転支援システム to the vocabulary
# Adding ミリ波 to the vocabulary
# Adding パワートレイン to the vocabulary
# Adding btob to the vocabulary
# Adding move to the vocabulary
# Adding 製造工程 to the vocabulary
# Adding インダストリアル to the vocabulary
# Adding コンシューマー to the vocabulary
# Adding 顕在 to the vocabulary
# Adding nand型フラッシュメモリ to the vocabulary
# Adding パワーデバイス to the vocabulary
# Adding ファウンドリ to the vocabulary
# Adding 半導体メーカー to the vocabulary
# Adding テスタ to the vocabulary
# Adding map to the vocabulary
# Adding ハンドラ to the vocabulary
# Adding ウェハパラレルテスタ to the vocabulary
# Adding ウェハプローバ・テスタ to the vocabulary
# Adding 一体型 to the vocabulary
# Adding 顧客層 to the vocabulary
# Adding ca to the vocabulary
# Adding qcd to the vocabulary
# Adding ワシントン州 to the vocabulary
# Adding 完納 to the vocabulary
# Adding 運賃箱 to the vocabulary
# Adding obc to the vocabulary
# Adding ems to the vocabulary
# Adding 無停電電源装置 to the vocabulary
# Adding 変圧器 to the vocabulary
# Adding プリント基板 to the vocabulary
# Adding レシップホールディングス株式会社 to the vocabulary
# Adding 不動産賃貸業 to the vocabulary
# Adding 下振れ to the vocabulary
# Adding 日産自動車株式会社 to the vocabulary
# Adding アルマーダ to the vocabulary
# Adding 売上台数 to the vocabulary
# Adding 商用車 to the vocabulary
# Adding シビリアン to the vocabulary
# Adding 税制改正 to the vocabulary
# Adding 円高ドル安 to the vocabulary
# Adding subaru to the vocabulary
# Adding 定時株主総会 to the vocabulary
# Adding 富士重工業株式会社 to the vocabulary
# Adding 株式会社subaru to the vocabulary
# Adding 社名変更 to the vocabulary
# Adding 世界販売 to the vocabulary
# Adding 連結決算 to the vocabulary
# Adding エアバッグインフレータ to the vocabulary
# Adding エアバッグ to the vocabulary
# Adding ライトトラック to the vocabulary
# Adding インプレッサ to the vocabulary
# Adding レヴォーグ to the vocabulary
# Adding フォレスター to the vocabulary
# Adding シフォン to the vocabulary
# Adding アウトバック to the vocabulary
# Adding モーティブ to the vocabulary
# Adding sia to the vocabulary
# Adding クロストレック to the vocabulary
# Adding 日本名 to the vocabulary
# Adding xv to the vocabulary
# Adding 豪州 to the vocabulary
# Adding 新多 to the vocabulary
# Adding uh to the vocabulary
# Adding ビークル to the vocabulary
# Adding 国民投票 to the vocabulary
# Adding 企業体 to the vocabulary
# Adding 経営管理 to the vocabulary
# Adding グローバル化 to the vocabulary
# Adding 最適化 to the vocabulary
# Adding ヘッドアップディスプレイ to the vocabulary
# Adding ns to the vocabulary
# Adding 増員 to the vocabulary
# Adding 製品化 to the vocabulary
# Adding 高信頼 to the vocabulary
# Adding smash to the vocabulary
# Adding smart to the vocabulary
# Adding sharing to the vocabulary
# Adding 深堀 to the vocabulary
# Adding 組合せ to the vocabulary
# Adding oa to the vocabulary
# Adding 自動車販売事業 to the vocabulary
# Adding 物品税 to the vocabulary
# Adding ロッカーアーム to the vocabulary
# Adding 圧縮効果 to the vocabulary
# Adding 立上 to the vocabulary
# Adding げた to the vocabulary
# Adding レジオネラ菌 to the vocabulary
# Adding 課徴金 to the vocabulary
# Adding 自然界 to the vocabulary
# Adding 冷却水 to the vocabulary
# Adding 給湯器 to the vocabulary
# Adding 高熱 to the vocabulary
# Adding 咳 to the vocabulary
# Adding 筋肉痛 to the vocabulary
# Adding 車検 to the vocabulary
# Adding 軽微 to the vocabulary
# Adding 年初来 to the vocabulary
# Adding 年度内 to the vocabulary
# Adding ワールドワイド to the vocabulary
# Adding 中小企業 to the vocabulary
# Adding 短観 to the vocabulary
# Adding 減退 to the vocabulary
# Adding dram to the vocabulary
# Adding フラッシュメモリ to the vocabulary
# Adding 下方修正 to the vocabulary
# Adding cd to the vocabulary
# Adding sem to the vocabulary
# Adding zx to the vocabulary
# Adding ジーテン to the vocabulary
# Adding 初号 to the vocabulary
# Adding 節減 to the vocabulary
# Adding プレイス to the vocabulary
# Adding 据置 to the vocabulary
# Adding テレビゲーム機 to the vocabulary
# Adding nintendo to the vocabulary
# Adding switch to the vocabulary
# Adding 滑り出し to the vocabulary
# Adding ゼルダの伝説　ブレス to the vocabulary
# Adding wii to the vocabulary
# Adding 万本 to the vocabulary
# Adding ニンテンドーds to the vocabulary
# Adding ポケットモンスター to the vocabulary
# Adding サン・ムーン to the vocabulary
# Adding スーパーマリオメーカー to the vocabulary
# Adding 星のカービィ to the vocabulary
# Adding ロボボプラネット to the vocabulary
# Adding スマートデバイス to the vocabulary
# Adding pokémon to the vocabulary
# Adding 期初 to the vocabulary
# Adding アクションゲーム to the vocabulary
# Adding スーパーマリオ to the vocabulary
# Adding ios版 to the vocabulary
# Adding android版 to the vocabulary
# Adding シミュレーションrpg to the vocabulary
# Adding ゲームアプリ to the vocabulary
# Adding ファイアーエムブレム to the vocabulary
# Adding ヒーローズ to the vocabulary
# Adding 専用機 to the vocabulary
# Adding ニンテンドークラシックミニ to the vocabulary
# Adding ファミリーコンピュータ to the vocabulary
# Adding 日本版 to the vocabulary
# Adding amiibo to the vocabulary
# Adding アミーボ to the vocabulary
# Adding 株式会社ポケモン to the vocabulary
# Adding シアトルマリナーズ to the vocabulary
# Adding 運営会社 to the vocabulary
# Adding civic to the vocabulary
# Adding フルモデルチェンジ to the vocabulary
# Adding 体質改善 to the vocabulary
# Adding 裁断 to the vocabulary
# Adding 新機種 to the vocabulary
# Adding 切替 to the vocabulary
# Adding リコール to the vocabulary
# Adding usドル to the vocabulary
# Adding ⇒ to the vocabulary
# Adding nsx to the vocabulary
# Adding ts to the vocabulary
# Adding tech to the vocabulary
# Adding alabama to the vocabulary
# Adding トリム to the vocabulary
# Adding avancier to the vocabulary
# Adding gienia to the vocabulary
# Adding 広州市 to the vocabulary
# Adding 増城区 to the vocabulary
# Adding 開発計画 to the vocabulary
# Adding 生産ライン to the vocabulary
# Adding 製造物流 to the vocabulary
# Adding 導線 to the vocabulary
# Adding bangladesh to the vocabulary
# Adding 模倣品 to the vocabulary
# Adding チェーン店 to the vocabulary
# Adding 倹約 to the vocabulary
# Adding 不動産市場 to the vocabulary
# Adding 過熱感 to the vocabulary
# Adding 資本流出 to the vocabulary
# Adding brexit to the vocabulary
# Adding 顕在化 to the vocabulary
# Adding operational to the vocabulary
# Adding excellence to the vocabulary
# Adding 業務改善 to the vocabulary
# Adding specification to the vocabulary
# Adding multiple to the vocabulary
# Adding インセンティブ to the vocabulary
# Adding ストックオプション to the vocabulary
# Adding エンプラ to the vocabulary
# Adding 生産調整 to the vocabulary
# Adding オプト to the vocabulary
# Adding ハイエンド to the vocabulary
# Adding コンタクトレンズ to the vocabulary
# Adding 方々 to the vocabulary
# Adding 必需品 to the vocabulary
# Adding 使い捨て to the vocabulary
# Adding 遠近 to the vocabulary
# Adding シリコーンハイドロゲル to the vocabulary
# Adding 乱視 to the vocabulary
# Adding ヶ年 to the vocabulary
# Adding 管理体制 to the vocabulary
# Adding ピュア to the vocabulary
# Adding シードアイコフレワンデー to the vocabulary
# Adding uv to the vocabulary
# Adding ヒロインメイク to the vocabulary
# Adding ワンデーピュアシリーズ to the vocabulary
# Adding アイコフレワンデー to the vocabulary
# Adding ビビッドムーン to the vocabulary
# Adding 販売終了 to the vocabulary
# Adding 配荷 to the vocabulary
# Adding 終売 to the vocabulary
# Adding 一本化 to the vocabulary
# Adding ライフサイエンス to the vocabulary
# Adding プロテクトフィルム to the vocabulary
# Adding 日用品 to the vocabulary
# Adding パウチ to the vocabulary
# Adding 剥離 to the vocabulary
# Adding プロテクト to the vocabulary
# Adding ボイドスラブ to the vocabulary
# Adding 増額 to the vocabulary
# Adding 概観 to the vocabulary
# Adding 税制改革 to the vocabulary
# Adding 財政政策 to the vocabulary
# Adding 内需拡大 to the vocabulary
# Adding 過剰生産 to the vocabulary
# Adding 重荷 to the vocabulary
# Adding 踊り場 to the vocabulary
# Adding 豊田通商グループ to the vocabulary
# Adding 連結納税 to the vocabulary
# Adding tt to the vocabulary
# Adding steel to the vocabulary
# Adding service to the vocabulary
# Adding 原料調達 to the vocabulary
# Adding ガバナンス to the vocabulary
# Adding 豊通 to the vocabulary
# Adding 豊通レアアース株式会社 to the vocabulary
# Adding 吸収合併 to the vocabulary
# Adding 業務内容 to the vocabulary
# Adding toyotsu to the vocabulary
# Adding smelting to the vocabulary
# Adding mexico to the vocabulary
# Adding ダイキャスト to the vocabulary
# Adding 溶湯 to the vocabulary
# Adding ロジスティクス to the vocabulary
# Adding 燃料電池 to the vocabulary
# Adding ballard to the vocabulary
# Adding systems to the vocabulary
# Adding bolloré to the vocabulary
# Adding transport to the vocabulary
# Adding logistics to the vocabulary
# Adding kenya to the vocabulary
# Adding 日本郵船株式会社 to the vocabulary
# Adding nyk to the vocabulary
# Adding nexen to the vocabulary
# Adding tire to the vocabulary
# Adding ネクセンタイヤジャパン to the vocabulary
# Adding toyota to the vocabulary
# Adding uganda to the vocabulary
# Adding ユーラスエナジーホールディングス to the vocabulary
# Adding 風力発電 to the vocabulary
# Adding ハワイ州 to the vocabulary
# Adding 太陽光発電所 to the vocabulary
# Adding 変電所 to the vocabulary
# Adding tsusho to the vocabulary
# Adding fertilizer to the vocabulary
# Adding 株式会社トーメンエレクトロニクス to the vocabulary
# Adding 株式会社豊通エレクトロニクス to the vocabulary
# Adding 株式会社ネクス to the vocabulary
# Adding サッポロ to the vocabulary
# Adding country to the vocabulary
# Adding pure to the vocabulary
# Adding foods to the vocabulary
# Adding シャーベット to the vocabulary
# Adding ridgefield to the vocabulary
# Adding brand to the vocabulary
# Adding 長期滞在者 to the vocabulary
# Adding レジデンス to the vocabulary
# Adding axia to the vocabulary
# Adding south to the vocabulary
# Adding cikarang to the vocabulary
# Adding 持家 to the vocabulary
# Adding yuasa to the vocabulary
# Adding legacy to the vocabulary
# Adding くらし to the vocabulary
# Adding 商圏 to the vocabulary
# Adding 中米 to the vocabulary
# Adding 創エネ to the vocabulary
# Adding 蓄エネ to the vocabulary
# Adding zeh to the vocabulary
# Adding 新エネルギー to the vocabulary
# Adding 防災倉庫 to the vocabulary
# Adding 模擬訓練 to the vocabulary
# Adding 減災 to the vocabulary
# Adding bcp to the vocabulary
# Adding 事業継続計画 to the vocabulary
# Adding ユアサ商事 to the vocabulary
# Adding 自己資本 to the vocabulary
# Adding о to the vocabulary
# Adding 総資産 to the vocabulary
# Adding 関連産業 to the vocabulary
# Adding 切削工具 to the vocabulary
# Adding コンプレッサ to the vocabulary
# Adding マテハン to the vocabulary
# Adding 周辺機器 to the vocabulary
# Adding 期末 to the vocabulary
# Adding 来期 to the vocabulary
# Adding 管材 to the vocabulary
# Adding 蓄電池 to the vocabulary
# Adding 空調機器 to the vocabulary
# Adding エクステリア to the vocabulary
# Adding 門柱 to the vocabulary
# Adding 免震 to the vocabulary
# Adding レジリエンス to the vocabulary
# Adding ミニショベル to the vocabulary
# Adding 高所作業車 to the vocabulary
# Adding 石油製品 to the vocabulary
# Adding 低水準 to the vocabulary
# Adding コタツ to the vocabulary
# Adding 冬物 to the vocabulary
# Adding プライベートブランド商品 to the vocabulary
# Adding 合板 to the vocabulary
# Adding 木質 to the vocabulary
# Adding 消費者心理 to the vocabulary
# Adding 国際競争 to the vocabulary
# Adding 全体最適 to the vocabulary
# Adding 荷受 to the vocabulary
# Adding 中央卸売市場 to the vocabulary
# Adding ハマチ to the vocabulary
# Adding 水産加工 to the vocabulary
# Adding おにぎり to the vocabulary
# Adding 米飯 to the vocabulary
# Adding 仕分け to the vocabulary
# Adding 新車販売台数 to the vocabulary
# Adding 東京都内 to the vocabulary
# Adding デイズ to the vocabulary
# Adding デイズルークス to the vocabulary
# Adding セレナ to the vocabulary
# Adding 第三世代 to the vocabulary
# Adding ビッグデータ to the vocabulary
# Adding 落着 to the vocabulary
# Adding 税負担 to the vocabulary
# Adding 実体経済 to the vocabulary
# Adding 利幅 to the vocabulary
# Adding 欧州諸国 to the vocabulary
# Adding 経済圏 to the vocabulary
# Adding 受取配当金 to the vocabulary
# Adding 専門性 to the vocabulary
# Adding 組織変更 to the vocabulary
# Adding 電材 to the vocabulary
# Adding インキ to the vocabulary
# Adding 空調機 to the vocabulary
# Adding 難燃剤 to the vocabulary
# Adding レアアース to the vocabulary
# Adding タービンロータ to the vocabulary
# Adding plan to the vocabulary
# Adding 都市ガス to the vocabulary
# Adding 小売自由化 to the vocabulary
# Adding fc to the vocabulary
# Adding フォークリフト to the vocabulary
# Adding 山口県 to the vocabulary
# Adding 液化 to the vocabulary
# Adding 総合エネルギー to the vocabulary
# Adding 低位 to the vocabulary
# Adding ボンベ to the vocabulary
# Adding エアセパレートガス to the vocabulary
# Adding 物流システム to the vocabulary
# Adding 機械設備 to the vocabulary
# Adding pet to the vocabulary
# Adding ジルコン to the vocabulary
# Adding 畜肉 to the vocabulary
# Adding 頭数 to the vocabulary
# Adding 薬価基準 to the vocabulary
# Adding c型肝炎 to the vocabulary
# Adding マイナス成長 to the vocabulary
# Adding 調剤薬局 to the vocabulary
# Adding 存在価値 to the vocabulary
# Adding ビジネスモデル to the vocabulary
# Adding 共創未来ファーマ株式会社 to the vocabulary
# Adding ビジネススキーム to the vocabulary
# Adding 単品 to the vocabulary
# Adding 音声認識 to the vocabulary
# Adding 薬歴 to the vocabulary
# Adding enifvoice to the vocabulary
# Adding 初診 to the vocabulary
# Adding 調剤報酬 to the vocabulary
# Adding 標準化 to the vocabulary
# Adding 治験 to the vocabulary
# Adding イエリデザインプロダクツ to the vocabulary
# Adding ニット to the vocabulary
# Adding イエリデザイン to the vocabulary
# Adding 撚糸 to the vocabulary
# Adding 和装 to the vocabulary
# Adding 吉利 to the vocabulary
# Adding 洋装 to the vocabulary
# Adding 婦人服 to the vocabulary
# Adding 子供服 to the vocabulary
# Adding 受け売 to the vocabulary
# Adding めざし to the vocabulary
# Adding か年 to the vocabulary
# Adding メディパル to the vocabulary
# Adding next to the vocabulary
# Adding 事業統合 to the vocabulary
# Adding メディパルフーズ to the vocabulary
# Adding 札幌市中央区 to the vocabulary
# Adding 希少疾病用医薬品 to the vocabulary
# Adding スペシャリティ to the vocabulary
# Adding line株式会社 to the vocabulary
# Adding 東京都中央 to the vocabulary
# Adding アプリ開発 to the vocabulary
# Adding 株式会社エムティーアイ to the vocabulary
# Adding プレサスキューブ to the vocabulary
# Adding 東京都港区 to the vocabulary
# Adding 株式会社産業革新機構 to the vocabulary
# Adding 東京都千代田区 to the vocabulary
# Adding 武田薬品工業株式会社 to the vocabulary
# Adding 大阪市中央 to the vocabulary
# Adding 共同出資 to the vocabulary
# Adding 創薬 to the vocabulary
# Adding ベンチャー企業 to the vocabulary
# Adding スコヒアファーマ to the vocabulary
# Adding 神奈川県藤沢市 to the vocabulary
# Adding ピークアウト to the vocabulary
# Adding サプライチェーン to the vocabulary
# Adding アトル to the vocabulary
# Adding 福岡市東区 to the vocabulary
# Adding 株式会社メディセオ to the vocabulary
# Adding 埼玉県三郷市 to the vocabulary
# Adding エバルス to the vocabulary
# Adding 岡山県 to the vocabulary
# Adding 都窪郡 to the vocabulary
# Adding flc to the vocabulary
# Adding 品切れ to the vocabulary
# Adding presus to the vocabulary
# Adding プレサス to the vocabulary
# Adding mr to the vocabulary
# Adding 認定試験 to the vocabulary
# Adding 専門知識 to the vocabulary
# Adding pms to the vocabulary
# Adding area to the vocabulary
# Adding front to the vocabulary
# Adding pharmacy to the vocabulary
# Adding real to the vocabulary
# Adding time to the vocabulary
# Adding support to the vocabulary
# Adding 需要予測 to the vocabulary
# Adding 在庫管理 to the vocabulary
# Adding オールインワン to the vocabulary
# Adding assist to the vocabulary
# Adding representatives to the vocabulary
# Adding 担当者 to the vocabulary
# Adding 株式会社paltac to the vocabulary
# Adding 顧客満足 to the vocabulary
# Adding 最小化 to the vocabulary
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# input_idsと分散表現を連結
summaryOrg = torch.cat((input_ids.reshape(input_ids.shape[0], input_ids.shape[1], 1)
                        , last_hidden_states), dim=2)
print(summaryOrg.shape)
# Out:
# torch.Size([6099, 166, 769])

# %%
# %%time
# 共通する語彙の分散表現だけ集計
commonVocabs = wordMasterPart['lemma'].unique()  # 語彙
nonDelVocab = tokenizerOrg.encode(list(commonVocabs))  # WordNetにある単語のトークン
delVocab = [0.,1.,2.,3.,4.]  # 特殊トークン
summaryOrgTs = torch.Tensor()
for ts in tqdm(summaryOrg[:,:,:]):
    tmp = pd.DataFrame(ts[:,:].numpy())  #1行目の各トークンの分散表現
    tmp = tmp[tmp[0].isin(nonDelVocab)]  # WordNetにある単語のトークンは消さない
    tmp = tmp[~tmp[0].isin(delVocab)]  # 特殊トークン消す
    summaryOrgTs = torch.cat((summaryOrgTs, torch.tensor(tmp.to_numpy())))
display(tmp.head())  # 1列目はトークンid、2列目以降は分散表現
print(summaryOrgTs.shape)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 6099/6099 [01:53<00:00, 53.84it/s]
#         0         1        2         3         4         5         6    \
# 1   20525.0 -0.861274  0.18735  0.307756  0.020265  1.788669 -0.316896
# 2    5161.0 -0.861274  0.18735  0.307756  0.020265  1.788669 -0.316896
# 9   14461.0 -0.861274  0.18735  0.307756  0.020265  1.788669 -0.316896
# 15    701.0 -0.861274  0.18735  0.307756  0.020265  1.788669 -0.316896
# 16   1346.0 -0.861274  0.18735  0.307756  0.020265  1.788669 -0.316896
#
#          7        8         9    ...       759       760       761       762  \
# 1  -1.036553  0.56695 -0.691072  ... -2.849060  0.025727  1.643805  0.131071
# 2  -1.036553  0.56695 -0.691072  ... -2.849060  0.025727  1.643805  0.131071
# 9  -1.036554  0.56695 -0.691072  ... -2.849059  0.025727  1.643805  0.131071
# 15 -1.036553  0.56695 -0.691072  ... -2.849060  0.025727  1.643805  0.131071
# 16 -1.036553  0.56695 -0.691072  ... -2.849060  0.025727  1.643805  0.131071
#
#          763       764       765       766       767       768
# 1   1.233061 -2.362948 -1.608163 -0.891338 -0.069695 -0.461069
# 2   1.233061 -2.362948 -1.608163 -0.891339 -0.069695 -0.461069
# 9   1.233061 -2.362948 -1.608163 -0.891339 -0.069695 -0.461069
# 15  1.233061 -2.362948 -1.608163 -0.891338 -0.069695 -0.461069
# 16  1.233061 -2.362948 -1.608163 -0.891338 -0.069695 -0.461069
#
# [5 rows x 769 columns]
# torch.Size([38317, 769])
# Wall time: 1min 53s

# %%
# 複数の分散表現がある単語は平均とる
summaryOrgDf = pd.DataFrame(summaryOrgTs.numpy())
summaryOrgTsMean = torch.tensor(summaryOrgDf.groupby([0]).mean().reset_index().to_numpy())
# 語彙数
# Word2vecの方は787個
print(summaryOrgTsMean.shape[0])
# Out:
# 781

# %%
# Word2Vec学習時に定義した語彙のリスト vocabに出てくる単語を評価対象にする
# 各トークンのcos類似度が最も高いTop5のトークンを取得
# 同義語抽出評価

sameWordsCnt = 0  # 初期値 同義語の数
num=0  # カウントの変数
print('限定したWordNetの語彙数', wordMasterPart['lemma'].unique().shape[0])
print('限定したWordNetの語彙と共通する語彙数', summaryOrgTsMean[:,1:].shape[0])  # 限定したWordNetの語彙と共通する語彙数
print('限定したWordNetの単語にあるすべての同義語の数', allSameWordsCnt, '\n')
# 限定したWordNetの単語ごとの同義語についてモデルがいくつ同じ同義語を抽出できているかカウントする
for i, v1 in tqdm(enumerate(summaryOrgTsMean[:,1:])):
    # i行目のトークンidをdecode
    tango = tokenizerOrg.decode(int(summaryOrgTsMean[i,0].item())).replace(' ','')  # 変な空白が入っているときがあるので削除
    tagger = MeCab.Tagger()
    noun = re.split('[\t,]', tagger.parse(tango))[1]  # 品詞取得
    if noun!='名詞':  # 名詞以外のときはスキップ
        continue
    # 単語v1とv2のcos類似度を計算する
    cosList = []
    for j, v2 in (enumerate(summaryOrgTsMean[:,1:])):
        if i==j:
            cosList.append(0)
        else:
            cosList.append(1 - scipy.spatial.distance.cosine(v1, v2))  # cos類似度
    # cos類似度top5 Token取得
    top5Token = summaryOrgTsMean[list(np.argsort(cosList)[-5:][::-1]),0].tolist()
    top5Cos = [cosList[co] for co in list(np.argsort(cosList)[-5:][::-1])]
    top5 = [(tokenizerOrg.decode(int(to)).replace(' ',''), co) for to, co in zip(top5Token, top5Cos)]
    # tangoに最も似ている単語Top5をdfにまとめる
    tmp = pd.DataFrame(top5
                       , columns=['sameLemma', 'cos'])
    tmp.insert(0, 'lemma', tango)
    # 限定したWordNetと紐づける
    mergeDf = pd.merge(wordMasterPart[wordMasterPart['lemma']==tango][['lemma', 'sameLemma']].drop_duplicates()
                       , tmp, on=['lemma', 'sameLemma'], how='inner')
    # 紐づけたdfの結果
    if len(mergeDf) > 0:
        print(tango)
        display(mergeDf)
        print('===============', '\n')
    sameWordsCnt += len(mergeDf)  # 紐づけられた同義語の数を足す
    num += 1
# 最終的な正解数
print('正解数', str(sameWordsCnt), '/', allSameWordsCnt)
# Out:
# 限定したWordNetの語彙数 787
# 限定したWordNetの語彙と共通する語彙数 781
# 限定したWordNetの単語にあるすべての同義語の数 2810
# 15it [00:00, 27.44it/s]
# 種
#   lemma sameLemma  cos
# 0     種         材  1.0
# 21it [00:00, 26.58it/s]
# ===============
# 24it [00:00, 25.77it/s]
# 一部
#   lemma sameLemma  cos
# 0    一部        部門  1.0
# 30it [00:01, 24.94it/s]
# ===============
# 45it [00:01, 25.55it/s]
# 地方
#   lemma sameLemma  cos
# 0    地方        地域  1.0
# 51it [00:01, 25.03it/s]
# ===============
#
# 変更
#   lemma sameLemma  cos
# 0    変更        変化  1.0
# 57it [00:02, 25.24it/s]
# ===============
#
# 建設
#   lemma sameLemma  cos
# 0    建設        製造  1.0
# 60it [00:02, 25.17it/s]
# ===============
#
# 当初
#   lemma sameLemma  cos
# 0    当初        開始  1.0
# 63it [00:02, 24.62it/s]
# ===============
# 87it [00:03, 25.50it/s]
# 製造
#   lemma sameLemma  cos
# 0    製造        建設  1.0
# 93it [00:03, 25.26it/s]
# ===============
# 112it [00:04, 26.86it/s]
# モデル
#   lemma sameLemma  cos
# 0   モデル         型  1.0
# 118it [00:04, 25.66it/s]
# ===============
# 139it [00:05, 25.91it/s]
# 連続
#   lemma sameLemma  cos
# 0    連続        継続  1.0
# 145it [00:05, 25.67it/s]
# ===============
# 160it [00:06, 25.61it/s]
# 変化
#   lemma sameLemma  cos
# 0    変化        変動  1.0
# 166it [00:06, 25.37it/s]
# ===============
# 187it [00:07, 26.04it/s]
# 部門
#   lemma sameLemma  cos
# 0    部門        領域  1.0
# 190it [00:07, 25.50it/s]
# ===============
#
# 産業
#   lemma sameLemma  cos
# 0    産業        加工  1.0
# 196it [00:07, 25.29it/s]
# ===============
# 202it [00:07, 25.12it/s]
# 通信
#   lemma sameLemma  cos
# 0    通信        情報  1.0
# 208it [00:08, 25.11it/s]
# ===============
# 220it [00:08, 25.86it/s]
# 安全
#   lemma sameLemma  cos
# 0    安全        確保  1.0
# 226it [00:08, 25.68it/s]
# ===============
# 241it [00:09, 25.98it/s]
# 加入
#   lemma sameLemma  cos
# 0    加入        合併  1.0
# 247it [00:09, 25.60it/s]
# ===============
# 256it [00:10, 25.27it/s]
# 役割
#   lemma sameLemma  cos
# 0    役割        目的  1.0
# 262it [00:10, 25.44it/s]
# ===============
# 265it [00:10, 25.50it/s]
# 強化
#   lemma sameLemma  cos
# 0    強化        増強  1.0
# 271it [00:10, 25.53it/s]
# ===============
# 295it [00:11, 26.12it/s]
# 網
#   lemma sameLemma  cos
# 0     網    ネットワーク  1.0
# 301it [00:11, 26.07it/s]
# ===============
# 334it [00:13, 23.74it/s]
# 分析
#   lemma sameLemma  cos
# 0    分析        研修  1.0
# 337it [00:13, 23.87it/s]
# ===============
# 373it [00:14, 25.65it/s]
# 保有
#   lemma sameLemma  cos
# 0    保有        保守  1.0
# 379it [00:14, 25.33it/s]
# ===============
# 388it [00:15, 25.76it/s]
# 創業
#   lemma sameLemma  cos
# 0    創業        設立  1.0
# 394it [00:15, 25.51it/s]
# ===============
# 403it [00:15, 25.70it/s]
# 不安
#   lemma sameLemma  cos
# 0    不安        懸念  1.0
# 409it [00:16, 24.83it/s]
# ===============
# 415it [00:16, 25.41it/s]
# 修正
#   lemma sameLemma  cos
# 0    修正        変化  1.0
# 418it [00:16, 25.03it/s]
# ===============
#
# 加工
#   lemma sameLemma  cos
# 0    加工        産業  1.0
# ===============
# 490it [00:19, 23.58it/s]
# 創造
#   lemma sameLemma  cos
# 0    創造        設立  1.0
# 496it [00:19, 23.88it/s]
# ===============
# 604it [00:23, 25.96it/s]
# 遂行
#   lemma sameLemma  cos
# 0    遂行        実施  1.0
# 610it [00:23, 25.65it/s]
# ===============
# 658it [00:25, 26.06it/s]
# 変革
#   lemma sameLemma  cos
# 0    変革        変化  1.0
# 661it [00:25, 25.67it/s]
# ===============
#
# 貸出
#   lemma sameLemma  cos
# 0    貸出       リース  1.0
# 664it [00:25, 24.83it/s]
# ===============
# 781it [00:30, 25.62it/s]
# 正解数 28 / 2810

# %% [markdown]
# ## Wikipedia学習済みWord2Vec評価

# %%
# Word2Vec学習時に定義した語彙のリスト vocabに出てくる単語を評価対象にする
# 同義語抽出評価

sameWordsCnt = 0  # 初期値 同義語の数
print('限定したWordNetの語彙数', wordMasterPart['lemma'].unique().shape[0])
# 重複する単語を抽出して長さ確認
print('限定したWordNetの語彙と共通する語彙数'
      , len([k for k, v in collections.Counter(list(wordMasterPart['lemma'].unique())+index2wordPre).items() if v > 1]))
print('限定したWordNetの単語にあるすべての同義語の数', allSameWordsCnt, '\n')
# 限定したWordNetの単語ごとの同義語についてモデルがいくつ同じ同義語を抽出できているかカウントする
for i, tango in tqdm(enumerate(wordMasterPart['lemma'].unique())):
    try:
        # tango=WordNetの単語1つずつループ
        # tangoに最も似ている単語Top5をdfにまとめる
        w2vCosDf = pd.DataFrame(wv_modelPre.most_similar(tango), columns=['sameLemma', 'cos'])
        w2vCosDf.insert(0, 'lemma', tango)
        # 限定したWordNetと紐づける
        mergeDf = pd.merge(wordMasterPart[wordMasterPart['lemma']==tango][['lemma', 'sameLemma']].drop_duplicates()
                           , w2vCosDf, on=['lemma', 'sameLemma'], how='inner')
        # 紐づけたdfの結果(数が多いので出力しない)
        #if len(mergeDf) > 0:
        #    print(tango)
        #    display(mergeDf)
        #    print('===============', '\n')
        sameWordsCnt += len(mergeDf)  # 紐づけられた同義語の数を足す
    except KeyError:
        'A tango not present'
# 最終的な正解数
print('正解数', str(sameWordsCnt), '/', allSameWordsCnt)
# Out:
# 限定したWordNetの語彙数 787
# 限定したWordNetの語彙と共通する語彙数 782
# 限定したWordNetの単語にあるすべての同義語の数 2810
# 787it [00:44, 17.54it/s]
# 正解数 426 / 2810

# %% [markdown]
# ## Wikipedia学習済みBERT評価

# %%
# いろいろ読み込み

# 最後の隠れ層ベクトルLoad
last_hidden_states = torch.load('bert_test/last_hidden_states02.pt')

# 東北大学の学習済みmodelを使用する
model_name = 'cl-tohoku/bert-base-japanese-whole-word-masking'
# トークナイザーの読み込み
tokenizerPre = BertJapaneseTokenizer.from_pretrained(model_name)
# 学習済みモデルの読み込み
bertModelPre = BertModel.from_pretrained(model_name)
# 東北大学の学習済みTokenizerで分かち書き
encoded = tokenizerPre.batch_encode_plus(sentenceDf['preprocessingSentence'].to_list(), padding=True, add_special_tokens=True)
print(encoded.keys())
print(len(encoded['input_ids'][0]))  # input_idsの1文書の長さ
# 学習済みBERTトークンID列を抽出
input_ids = torch.tensor(encoded['input_ids'])[:,:]
print(input_ids.shape)  # input_idsの型 文書数×1文書の長さ
# Out:
# loading file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/vocab.txt from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\15164357d71cd32532e56c1d7c2757141326ae17c53e2277bc417cc7c21da6ea.a7378a0cbee5cff668832a776d72b97a25479604fe9564d5595897f75049e7f4
# loading file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/tokenizer_config.json from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\0e46f722799f19c3f0c53172545108a4b31847d3b9a2d5b100759f6673bd667b.08ae4e4044742b9cc7172698caf1da2524f5597ff8cf848114dd0b730cc44bdc
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.20.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading weights file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/pytorch_model.bin from cache at C:\Users\yusuke.kiridoshi/.cache\huggingface\transformers\cabd9bbd81093f4c494a02e34eb57e405b7564db216404108c8e8caf10ede4fa.464b54997e35e3cc3223ba6d7f0abdaeb7be5b7648f275f57d839ee0f95611fb
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of BertModel were initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertModel for predictions without further training.
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# 258
# torch.Size([6099, 258])

# %%
# input_idsと分散表現を連結
summaryOrgPre = torch.cat((input_ids.reshape(input_ids.shape[0], input_ids.shape[1], 1)
                           , last_hidden_states), dim=2)
print(summaryOrgPre.shape)
# Out:
# torch.Size([6099, 258, 769])

# %%
# %%time
# 共通する語彙の分散表現だけ集計
nonDelVocab = tokenizerPre.encode(list(commonVocabs))  # WordNetにある単語のトークン
delVocab = [0.,1.,2.,3.,4.]  # 特殊トークン
summaryOrgTsPre = torch.Tensor()
for ts in tqdm(summaryOrgPre[:,:,:]):
    tmp = pd.DataFrame(ts[:,:].numpy())  #1行目の各トークンの分散表現
    tmp = tmp[tmp[0].isin(nonDelVocab)]  # WordNetにある単語のトークンは消さない
    tmp = tmp[~tmp[0].isin(delVocab)]  # 特殊トークン消す
    summaryOrgTsPre = torch.cat((summaryOrgTsPre, torch.tensor(tmp.to_numpy())))
display(tmp.head())  # 1列目はトークンid、2列目以降は分散表現
print(summaryOrgTsPre.shape)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (789 > 512). Running this sequence through the model will result in indexing errors
# 100%|██████████████████████████████████████████████████████████████████████████████| 6099/6099 [02:34<00:00, 39.58it/s]
#         0         1         2         3         4         5         6    \
# 1   20525.0 -0.468271  0.749700 -0.195274 -0.249739 -0.499166 -0.072858
# 2    5161.0 -0.394134  0.603517  0.310727 -0.329336 -0.618172  0.061398
# 3    1790.0 -0.321748  0.631709  0.006191 -0.340471 -0.251261 -0.385065
# 4    5161.0 -0.242368  0.544518  0.270213 -0.370365 -0.563863  0.015539
# 10  14461.0 -0.517592  0.699880  0.002472 -0.252257 -0.665148 -0.155570
#
#          7         8         9    ...       759       760       761       762  \
# 1   0.105265  0.004123 -0.028559  ... -0.198605 -0.194617  0.102433  0.397646
# 2   0.102205  0.118264  0.401545  ... -0.324053 -0.292790  0.214343  0.387949
# 3   0.024060  0.172158  0.331330  ... -0.151674 -0.108270  0.100474  0.453578
# 4   0.023054 -0.032608  0.436251  ... -0.206094 -0.402527  0.337104  0.260721
# 10  0.149252  0.078627  0.208231  ... -0.136309 -0.147250 -0.083597  0.295493
#
#          763       764       765       766       767       768
# 1  -0.095702 -0.642062 -0.211784 -0.393812 -1.054616  0.392896
# 2   0.199548 -0.768709 -0.009901 -0.413048 -1.160358  0.262009
# 3   0.067145 -0.789796 -0.125366 -0.339459 -1.022954  0.194144
# 4   0.113517 -0.846188  0.169125 -0.277054 -1.064100  0.378227
# 10  0.209624 -0.770756 -0.044984 -0.271981 -1.164710  0.711935
#
# [5 rows x 769 columns]
# torch.Size([52080, 769])
# Wall time: 2min 34s

# %%
# 複数の分散表現がある単語は平均とる
summaryOrgDfPre = pd.DataFrame(summaryOrgTsPre.numpy())
summaryOrgTsPreMean = torch.tensor(summaryOrgDfPre.groupby([0]).mean().reset_index().to_numpy())
# 語彙数
# Word2vecの方は787個
print(summaryOrgTsPreMean.shape[0])
# Out:
# 718

# %%
# Word2Vec学習時に定義した語彙のリスト vocabに出てくる単語を評価対象にする
# 各トークンのcos類似度が最も高いTop5のトークンを取得
# 同義語抽出評価

sameWordsCnt = 0  # 初期値 同義語の数
num=0  # カウントの変数
print('限定したWordNetの語彙数', wordMasterPart['lemma'].unique().shape[0])
print('限定したWordNetの語彙と共通する語彙数', summaryOrgTsPreMean[:,1:].shape[0])  # 限定したWordNetの語彙と共通する語彙数
print('限定したWordNetの単語にあるすべての同義語の数', allSameWordsCnt, '\n')
# 限定したWordNetの単語ごとの同義語についてモデルがいくつ同じ同義語を抽出できているかカウントする
for i, v1 in tqdm(enumerate(summaryOrgTsPreMean[:,1:])):
    # i行目のトークンidをdecode
    tango = tokenizerOrg.decode(int(summaryOrgTsPreMean[i,0].item())).replace(' ','')  # 変な空白は言っているときがあるので削除
    tagger = MeCab.Tagger()
    noun = re.split('[\t,]', tagger.parse(tango))[1]  # 品詞取得
    if noun!='名詞':  # 名詞のときはスキップ
        continue
    # 単語v1とv2のcos類似度を計算する
    cosList = []
    for j, v2 in (enumerate(summaryOrgTsPreMean[:,1:])):
        if i==j:
            cosList.append(0)
        else:
            cosList.append(1 - scipy.spatial.distance.cosine(v1, v2))  # cos類似度
    # cos類似度top5 Token取得
    top5Token = summaryOrgTsPreMean[list(np.argsort(cosList)[-5:][::-1]),0].tolist()
    top5Cos = [cosList[co] for co in list(np.argsort(cosList)[-5:][::-1])]
    top5 = [(tokenizerOrg.decode(int(to)).replace(' ',''), co) for to, co in zip(top5Token, top5Cos)]
    # tangoに最も似ている単語Top5をdfにまとめる
    tmp = pd.DataFrame(top5
                       , columns=['sameLemma', 'cos'])
    tmp.insert(0, 'lemma', tango)
    # 限定したWordNetと紐づける
    mergeDf = pd.merge(wordMasterPart[wordMasterPart['lemma']==tango][['lemma', 'sameLemma']].drop_duplicates()
                       , tmp, on=['lemma', 'sameLemma'], how='inner')
    # 紐づけたdfの結果(数が多いので出力しない)
    #if len(mergeDf) > 0:
    #    print(tango)
    #    display(mergeDf)
    #    print('===============', '\n')
    sameWordsCnt += len(mergeDf)  # 紐づけられた同義語の数を足す
    num += 1
# 最終的な正解数
print('正解数', str(sameWordsCnt), '/', allSameWordsCnt)
# Out:
# 限定したWordNetの語彙数 787
# 限定したWordNetの語彙と共通する語彙数 718
# 限定したWordNetの単語にあるすべての同義語の数 2810
# 718it [00:26, 26.72it/s]
# 正解数 673 / 2810
